# %% [markdown]
# # CTI-MCQ

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import google.generativeai as genai


with open('gemini_key.txt', 'r') as file:
    GOOGLE_API_KEY = file.read().strip()
        
    genai.configure(api_key=GOOGLE_API_KEY)
        
    model = genai.GenerativeModel('gemini-1.5-flash')

with open('cti_mcq_generated.tsv', 'a') as file:
    file.write('URL' + '\t' + 'Question' + '\t' + 'Option A' + '\t' + 'Option B' + '\t' + 'Option C' + '\t' + 'Option D' 
               + '\t' + 'GT' + '\t' + 'Prompt' + '\n')
    

url = 'https://attack.mitre.org'
    
# Fetch the webpage
response = requests.get(url)

webpage_content = response.text

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(webpage_content, 'html.parser')

div_element = soup.find_all('div', class_="technique-cell")

# Find the a tag within the div element
for div in div_element:
    a_tag = div.find('a')
    
    # Get the text in the href attribute
    href_text = a_tag['href']
    
    response = requests.get('https://attack.mitre.org'+href_text)
    
    # Check if the request was successful
    if response.status_code == 200:
        webpage_content = response.text
        print('Webpage fetched successfully', href_text)
    
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(webpage_content, 'html.parser')

        try:
            paragraphe = soup.find_all('div', class_="description-body")[0].get_text().strip()
        except:
            continue
    
        # Find all tables with class "tables-mobile"
        tables = soup.find_all('div', class_="tables-mobile")
    
        res = []
        
        # Extract and print the content of each table
        for i, table in enumerate(tables, start=1):
            res.append([])
            #print(f'Table {i}:')
            rows = table.find_all('tr')
            for row in rows:
                cols = row.find_all(['th', 'td'])
                cols = [col.get_text().strip() for col in cols]
                res[-1].append(cols)
                #print('\t'.join(cols))
            #print('\n' + '-'*50 + '\n')

        if len(res) < 2:
            continue

        prompt = """You are a cybersecurity expert specializing in cyber threat intelligence. Given the text below, please generate a maximum of 5 multiple-choice questions with four possible options each.

        Follow these requirements:
        
        1. Question Format: Each question must have four options. The options should be challenging and require careful consideration. Avoid creating options that could be interpreted as correct under different circumstances.
        
        2. Target Audience: The questions should be suitable for security professionals with three to five years of experience in cyber threat intelligence. Avoid generic questions such as "What is the objective?", "Which operating system can be targeted?".
        
        3. Content Coverage: Aim to cover various sections of the document to ensure a comprehensive evaluation of the candidate's knowledge. Include context-specific questions that require an understanding of the document's content.
        
        4. Technical Precision: Use precise terminology and concepts relevant to cyber threat intelligence. Incorporate situational or scenario-based questions where applicable.
        
        5. Include Technique IDs and Names: Ensure that all questions, where applicable, mention both the ID and the full name of the MITRE ATT&CK pattern technique.
        
        6. Premise Inclusion: Each question should include a premise indicating it pertains to MITRE ATT&CK, specifying the relevant platform (Enterprise, ICS, or Mobile) where necessary.
        
        7. Output Format: Return the output in TSV format (must be tab-separated) with the following columns:
        Question, Option A, Option B, Option C, Option D and Correct Answer (A, B, C, D).
        
        Important: Only return the TSV (tab separator \t) content as specified. Do not include any additional text or commentary outside the TSV format.
        
        Text:
        
        """ + paragraphe + str(res)
        
        response = model.generate_content(prompt)

        try:
            with open('cti_mcq_generated.tsv', 'a') as file:
                for line in response.text.strip().split('\n')[1:]:
                    options=line.split('\t')
                    prompt = """You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.

Question:
"""+ options[0] +"""

 Options:
 A) """+ options[1] +"""
 B) """+ options[2] +"""
 C) """+ options[3] +"""
 D) """+ options[4] +"""

Important: The last line of your answer should contain only the single letter corresponding to the best option, with no additional text."""
                    file.write(url+href_text + '\t' + line + '\t' + prompt.replace('\n',' ').replace('\t',' ') + '\n')
        except:
            continue
    
    else:
        print(f'Failed to fetch webpage. Status code: {response.status_code}', href_text)
# Out:
# Webpage fetched successfully /techniques/T1595
# Webpage fetched successfully /techniques/T1595/001
# Webpage fetched successfully /techniques/T1595/002
# Webpage fetched successfully /techniques/T1595/003
# Webpage fetched successfully /techniques/T1592
# Webpage fetched successfully /techniques/T1592/001
# Webpage fetched successfully /techniques/T1592/002
# Webpage fetched successfully /techniques/T1592/003
# Webpage fetched successfully /techniques/T1592/004
# Webpage fetched successfully /techniques/T1589
# Webpage fetched successfully /techniques/T1589/001
# Webpage fetched successfully /techniques/T1589/002
# Webpage fetched successfully /techniques/T1589/003
# Webpage fetched successfully /techniques/T1590
# Webpage fetched successfully /techniques/T1590/001
# Webpage fetched successfully /techniques/T1590/002
# Webpage fetched successfully /techniques/T1590/003
# Webpage fetched successfully /techniques/T1590/004
# Webpage fetched successfully /techniques/T1590/005
# Webpage fetched successfully /techniques/T1590/006
# Webpage fetched successfully /techniques/T1591
# Webpage fetched successfully /techniques/T1591/001
# Webpage fetched successfully /techniques/T1591/002
# Webpage fetched successfully /techniques/T1591/003
# Webpage fetched successfully /techniques/T1591/004
# Webpage fetched successfully /techniques/T1598
# Webpage fetched successfully /techniques/T1598/001
# Webpage fetched successfully /techniques/T1598/002
# Webpage fetched successfully /techniques/T1598/003
# Webpage fetched successfully /techniques/T1598/004
# Webpage fetched successfully /techniques/T1597
# Webpage fetched successfully /techniques/T1597/001
# Webpage fetched successfully /techniques/T1597/002
# Webpage fetched successfully /techniques/T1596
# Webpage fetched successfully /techniques/T1596/001
# Webpage fetched successfully /techniques/T1596/002
# Webpage fetched successfully /techniques/T1596/003
# Webpage fetched successfully /techniques/T1596/004
# Webpage fetched successfully /techniques/T1596/005
# Webpage fetched successfully /techniques/T1593
# Webpage fetched successfully /techniques/T1593/001
# Webpage fetched successfully /techniques/T1593/002
# Webpage fetched successfully /techniques/T1593/003
# Webpage fetched successfully /techniques/T1594
# Webpage fetched successfully /techniques/T1650
# Webpage fetched successfully /techniques/T1583
# Webpage fetched successfully /techniques/T1583/001
# Webpage fetched successfully /techniques/T1583/002
# Webpage fetched successfully /techniques/T1583/003
# Webpage fetched successfully /techniques/T1583/004
# Webpage fetched successfully /techniques/T1583/005
# Webpage fetched successfully /techniques/T1583/006
# Webpage fetched successfully /techniques/T1583/007
# Webpage fetched successfully /techniques/T1583/008
# Webpage fetched successfully /techniques/T1586
# Webpage fetched successfully /techniques/T1586/001
# Webpage fetched successfully /techniques/T1586/002
# Webpage fetched successfully /techniques/T1586/003
# Webpage fetched successfully /techniques/T1584
# Webpage fetched successfully /techniques/T1584/001
# Webpage fetched successfully /techniques/T1584/002
# Webpage fetched successfully /techniques/T1584/003
# Webpage fetched successfully /techniques/T1584/004
# Webpage fetched successfully /techniques/T1584/005
# Webpage fetched successfully /techniques/T1584/006
# Webpage fetched successfully /techniques/T1584/007
# Webpage fetched successfully /techniques/T1584/008
# Webpage fetched successfully /techniques/T1587
# Webpage fetched successfully /techniques/T1587/001
# Webpage fetched successfully /techniques/T1587/002
# Webpage fetched successfully /techniques/T1587/003
# Webpage fetched successfully /techniques/T1587/004
# Webpage fetched successfully /techniques/T1585
# Webpage fetched successfully /techniques/T1585/001
# Webpage fetched successfully /techniques/T1585/002
# Webpage fetched successfully /techniques/T1585/003
# Webpage fetched successfully /techniques/T1588
# Webpage fetched successfully /techniques/T1588/001
# Webpage fetched successfully /techniques/T1588/002
# Webpage fetched successfully /techniques/T1588/003
# Webpage fetched successfully /techniques/T1588/004
# Webpage fetched successfully /techniques/T1588/005
# Webpage fetched successfully /techniques/T1588/006
# Webpage fetched successfully /techniques/T1588/007
# Webpage fetched successfully /techniques/T1608
# Webpage fetched successfully /techniques/T1608/001
# Webpage fetched successfully /techniques/T1608/002
# Webpage fetched successfully /techniques/T1608/003
# Webpage fetched successfully /techniques/T1608/004
# Webpage fetched successfully /techniques/T1608/005
# Webpage fetched successfully /techniques/T1608/006
# Webpage fetched successfully /techniques/T1659
# Webpage fetched successfully /techniques/T1189
# Webpage fetched successfully /techniques/T1190
# Webpage fetched successfully /techniques/T1133
# Webpage fetched successfully /techniques/T1200
# Webpage fetched successfully /techniques/T1566
# Webpage fetched successfully /techniques/T1566/001
# Webpage fetched successfully /techniques/T1566/002
# Webpage fetched successfully /techniques/T1566/003
# Webpage fetched successfully /techniques/T1566/004
# Webpage fetched successfully /techniques/T1091
# Webpage fetched successfully /techniques/T1195
# Webpage fetched successfully /techniques/T1195/001
# Webpage fetched successfully /techniques/T1195/002
# Webpage fetched successfully /techniques/T1195/003
# Webpage fetched successfully /techniques/T1199
# Webpage fetched successfully /techniques/T1078
# Webpage fetched successfully /techniques/T1078/001
# Webpage fetched successfully /techniques/T1078/002
# Webpage fetched successfully /techniques/T1078/003
# Webpage fetched successfully /techniques/T1078/004
# Webpage fetched successfully /techniques/T1651
# Webpage fetched successfully /techniques/T1059
# Webpage fetched successfully /techniques/T1059/001
# Webpage fetched successfully /techniques/T1059/002
# Webpage fetched successfully /techniques/T1059/003
# Webpage fetched successfully /techniques/T1059/004
# Webpage fetched successfully /techniques/T1059/005
# Webpage fetched successfully /techniques/T1059/006
# Webpage fetched successfully /techniques/T1059/007
# Webpage fetched successfully /techniques/T1059/008
# Webpage fetched successfully /techniques/T1059/009
# Webpage fetched successfully /techniques/T1059/010
# Webpage fetched successfully /techniques/T1609
# Webpage fetched successfully /techniques/T1610
# Webpage fetched successfully /techniques/T1203
# Webpage fetched successfully /techniques/T1559
# Webpage fetched successfully /techniques/T1559/001
# Webpage fetched successfully /techniques/T1559/002
# Webpage fetched successfully /techniques/T1559/003
# Webpage fetched successfully /techniques/T1106
# Webpage fetched successfully /techniques/T1053
# Webpage fetched successfully /techniques/T1053/002
# Webpage fetched successfully /techniques/T1053/003
# Webpage fetched successfully /techniques/T1053/005
# Webpage fetched successfully /techniques/T1053/006
# Webpage fetched successfully /techniques/T1053/007
# Webpage fetched successfully /techniques/T1648
# Webpage fetched successfully /techniques/T1129
# Webpage fetched successfully /techniques/T1072
# Webpage fetched successfully /techniques/T1569
# Webpage fetched successfully /techniques/T1569/001
# Webpage fetched successfully /techniques/T1569/002
# Webpage fetched successfully /techniques/T1204
# Webpage fetched successfully /techniques/T1204/001
# Webpage fetched successfully /techniques/T1204/002
# Webpage fetched successfully /techniques/T1204/003
# Webpage fetched successfully /techniques/T1047
# Webpage fetched successfully /techniques/T1098
# Webpage fetched successfully /techniques/T1098/001
# Webpage fetched successfully /techniques/T1098/002
# Webpage fetched successfully /techniques/T1098/003
# Webpage fetched successfully /techniques/T1098/004
# Webpage fetched successfully /techniques/T1098/005
# Webpage fetched successfully /techniques/T1098/006
# Webpage fetched successfully /techniques/T1197
# Webpage fetched successfully /techniques/T1547
# Webpage fetched successfully /techniques/T1547/001
# Webpage fetched successfully /techniques/T1547/002
# Webpage fetched successfully /techniques/T1547/003
# Webpage fetched successfully /techniques/T1547/004
# Webpage fetched successfully /techniques/T1547/005
# Webpage fetched successfully /techniques/T1547/006
# Webpage fetched successfully /techniques/T1547/007
# Webpage fetched successfully /techniques/T1547/008
# Webpage fetched successfully /techniques/T1547/009
# Webpage fetched successfully /techniques/T1547/010
# Webpage fetched successfully /techniques/T1547/012
# Webpage fetched successfully /techniques/T1547/013
# Webpage fetched successfully /techniques/T1547/014
# Webpage fetched successfully /techniques/T1547/015
# Webpage fetched successfully /techniques/T1037
# Webpage fetched successfully /techniques/T1037/001
# Webpage fetched successfully /techniques/T1037/002
# Webpage fetched successfully /techniques/T1037/003
# Webpage fetched successfully /techniques/T1037/004
# Webpage fetched successfully /techniques/T1037/005
# Webpage fetched successfully /techniques/T1176
# Webpage fetched successfully /techniques/T1554
# Webpage fetched successfully /techniques/T1136
# Webpage fetched successfully /techniques/T1136/001
# Webpage fetched successfully /techniques/T1136/002
# Webpage fetched successfully /techniques/T1136/003
# Webpage fetched successfully /techniques/T1543
# Webpage fetched successfully /techniques/T1543/001
# Webpage fetched successfully /techniques/T1543/002
# Webpage fetched successfully /techniques/T1543/003
# Webpage fetched successfully /techniques/T1543/004
# Webpage fetched successfully /techniques/T1543/005
# Webpage fetched successfully /techniques/T1546
# Webpage fetched successfully /techniques/T1546/001
# Webpage fetched successfully /techniques/T1546/002
# Webpage fetched successfully /techniques/T1546/003
# Webpage fetched successfully /techniques/T1546/004
# Webpage fetched successfully /techniques/T1546/005
# Webpage fetched successfully /techniques/T1546/006
# Webpage fetched successfully /techniques/T1546/007
# Webpage fetched successfully /techniques/T1546/008
# Webpage fetched successfully /techniques/T1546/009
# Webpage fetched successfully /techniques/T1546/010
# Webpage fetched successfully /techniques/T1546/011
# Webpage fetched successfully /techniques/T1546/012
# Webpage fetched successfully /techniques/T1546/013
# Webpage fetched successfully /techniques/T1546/014
# Webpage fetched successfully /techniques/T1546/015
# Webpage fetched successfully /techniques/T1546/016
# Webpage fetched successfully /techniques/T1133
# Webpage fetched successfully /techniques/T1574
# Webpage fetched successfully /techniques/T1574/001
# Webpage fetched successfully /techniques/T1574/002
# Webpage fetched successfully /techniques/T1574/004
# Webpage fetched successfully /techniques/T1574/005
# Webpage fetched successfully /techniques/T1574/006
# Webpage fetched successfully /techniques/T1574/007
# Webpage fetched successfully /techniques/T1574/008
# Webpage fetched successfully /techniques/T1574/009
# Webpage fetched successfully /techniques/T1574/010
# Webpage fetched successfully /techniques/T1574/011
# Webpage fetched successfully /techniques/T1574/012
# Webpage fetched successfully /techniques/T1574/013
# Webpage fetched successfully /techniques/T1574/014
# Webpage fetched successfully /techniques/T1525
# Webpage fetched successfully /techniques/T1556
# Webpage fetched successfully /techniques/T1556/001
# Webpage fetched successfully /techniques/T1556/002
# Webpage fetched successfully /techniques/T1556/003
# Webpage fetched successfully /techniques/T1556/004
# Webpage fetched successfully /techniques/T1556/005
# Webpage fetched successfully /techniques/T1556/006
# Webpage fetched successfully /techniques/T1556/007
# Webpage fetched successfully /techniques/T1556/008
# Webpage fetched successfully /techniques/T1556/009
# Webpage fetched successfully /techniques/T1137
# Webpage fetched successfully /techniques/T1137/001
# Webpage fetched successfully /techniques/T1137/002
# Webpage fetched successfully /techniques/T1137/003
# Webpage fetched successfully /techniques/T1137/004
# Webpage fetched successfully /techniques/T1137/005
# Webpage fetched successfully /techniques/T1137/006
# Webpage fetched successfully /techniques/T1653
# Webpage fetched successfully /techniques/T1542
# Webpage fetched successfully /techniques/T1542/001
# Webpage fetched successfully /techniques/T1542/002
# Webpage fetched successfully /techniques/T1542/003
# Webpage fetched successfully /techniques/T1542/004
# Webpage fetched successfully /techniques/T1542/005
# Webpage fetched successfully /techniques/T1053
# Webpage fetched successfully /techniques/T1053/002
# Webpage fetched successfully /techniques/T1053/003
# Webpage fetched successfully /techniques/T1053/005
# Webpage fetched successfully /techniques/T1053/006
# Webpage fetched successfully /techniques/T1053/007
# Webpage fetched successfully /techniques/T1505
# Webpage fetched successfully /techniques/T1505/001
# Webpage fetched successfully /techniques/T1505/002
# Webpage fetched successfully /techniques/T1505/003
# Webpage fetched successfully /techniques/T1505/004
# Webpage fetched successfully /techniques/T1505/005
# Webpage fetched successfully /techniques/T1205
# Webpage fetched successfully /techniques/T1205/001
# Webpage fetched successfully /techniques/T1205/002
# Webpage fetched successfully /techniques/T1078
# Webpage fetched successfully /techniques/T1078/001
# Webpage fetched successfully /techniques/T1078/002
# Webpage fetched successfully /techniques/T1078/003
# Webpage fetched successfully /techniques/T1078/004
# Webpage fetched successfully /techniques/T1548
# Webpage fetched successfully /techniques/T1548/001
# Webpage fetched successfully /techniques/T1548/002
# Webpage fetched successfully /techniques/T1548/003
# Webpage fetched successfully /techniques/T1548/004
# Webpage fetched successfully /techniques/T1548/005
# Webpage fetched successfully /techniques/T1548/006
# Webpage fetched successfully /techniques/T1134
# Webpage fetched successfully /techniques/T1134/001
# Webpage fetched successfully /techniques/T1134/002
# Webpage fetched successfully /techniques/T1134/003
# Webpage fetched successfully /techniques/T1134/004
# Webpage fetched successfully /techniques/T1134/005
# Webpage fetched successfully /techniques/T1098
# Webpage fetched successfully /techniques/T1098/001
# Webpage fetched successfully /techniques/T1098/002
# Webpage fetched successfully /techniques/T1098/003
# Webpage fetched successfully /techniques/T1098/004
# Webpage fetched successfully /techniques/T1098/005
# Webpage fetched successfully /techniques/T1098/006
# Webpage fetched successfully /techniques/T1547
# Webpage fetched successfully /techniques/T1547/001
# Webpage fetched successfully /techniques/T1547/002
# Webpage fetched successfully /techniques/T1547/003
# Webpage fetched successfully /techniques/T1547/004
# Webpage fetched successfully /techniques/T1547/005
# Webpage fetched successfully /techniques/T1547/006
# Webpage fetched successfully /techniques/T1547/007
# Webpage fetched successfully /techniques/T1547/008
# Webpage fetched successfully /techniques/T1547/009
# Webpage fetched successfully /techniques/T1547/010
# Webpage fetched successfully /techniques/T1547/012
# Webpage fetched successfully /techniques/T1547/013
# Webpage fetched successfully /techniques/T1547/014
# Webpage fetched successfully /techniques/T1547/015
# Webpage fetched successfully /techniques/T1037
# Webpage fetched successfully /techniques/T1037/001
# Webpage fetched successfully /techniques/T1037/002
# Webpage fetched successfully /techniques/T1037/003
# Webpage fetched successfully /techniques/T1037/004
# Webpage fetched successfully /techniques/T1037/005
# Webpage fetched successfully /techniques/T1543
# Webpage fetched successfully /techniques/T1543/001
# Webpage fetched successfully /techniques/T1543/002
# Webpage fetched successfully /techniques/T1543/003
# Webpage fetched successfully /techniques/T1543/004
# Webpage fetched successfully /techniques/T1543/005
# Webpage fetched successfully /techniques/T1484
# Webpage fetched successfully /techniques/T1484/001
# Webpage fetched successfully /techniques/T1484/002
# Webpage fetched successfully /techniques/T1611
# Webpage fetched successfully /techniques/T1546
# Webpage fetched successfully /techniques/T1546/001
# Webpage fetched successfully /techniques/T1546/002
# Webpage fetched successfully /techniques/T1546/003
# Webpage fetched successfully /techniques/T1546/004
# Webpage fetched successfully /techniques/T1546/005
# Webpage fetched successfully /techniques/T1546/006
# Webpage fetched successfully /techniques/T1546/007
# Webpage fetched successfully /techniques/T1546/008
# Webpage fetched successfully /techniques/T1546/009
# Webpage fetched successfully /techniques/T1546/010
# Webpage fetched successfully /techniques/T1546/011
# Webpage fetched successfully /techniques/T1546/012
# Webpage fetched successfully /techniques/T1546/013
# Webpage fetched successfully /techniques/T1546/014
# Webpage fetched successfully /techniques/T1546/015
# Webpage fetched successfully /techniques/T1546/016
# Webpage fetched successfully /techniques/T1068
# Webpage fetched successfully /techniques/T1574
# Webpage fetched successfully /techniques/T1574/001
# Webpage fetched successfully /techniques/T1574/002
# Webpage fetched successfully /techniques/T1574/004
# Webpage fetched successfully /techniques/T1574/005
# Webpage fetched successfully /techniques/T1574/006
# Webpage fetched successfully /techniques/T1574/007
# Webpage fetched successfully /techniques/T1574/008
# Webpage fetched successfully /techniques/T1574/009
# Webpage fetched successfully /techniques/T1574/010
# Webpage fetched successfully /techniques/T1574/011
# Webpage fetched successfully /techniques/T1574/012
# Webpage fetched successfully /techniques/T1574/013
# Webpage fetched successfully /techniques/T1574/014
# Webpage fetched successfully /techniques/T1055
# Webpage fetched successfully /techniques/T1055/001
# Webpage fetched successfully /techniques/T1055/002
# Webpage fetched successfully /techniques/T1055/003
# Webpage fetched successfully /techniques/T1055/004
# Webpage fetched successfully /techniques/T1055/005
# Webpage fetched successfully /techniques/T1055/008
# Webpage fetched successfully /techniques/T1055/009
# Webpage fetched successfully /techniques/T1055/011
# Webpage fetched successfully /techniques/T1055/012
# Webpage fetched successfully /techniques/T1055/013
# Webpage fetched successfully /techniques/T1055/014
# Webpage fetched successfully /techniques/T1055/015
# Webpage fetched successfully /techniques/T1053
# Webpage fetched successfully /techniques/T1053/002
# Webpage fetched successfully /techniques/T1053/003
# Webpage fetched successfully /techniques/T1053/005
# Webpage fetched successfully /techniques/T1053/006
# Webpage fetched successfully /techniques/T1053/007
# Webpage fetched successfully /techniques/T1078
# Webpage fetched successfully /techniques/T1078/001
# Webpage fetched successfully /techniques/T1078/002
# Webpage fetched successfully /techniques/T1078/003
# Webpage fetched successfully /techniques/T1078/004
# Webpage fetched successfully /techniques/T1548
# Webpage fetched successfully /techniques/T1548/001
# Webpage fetched successfully /techniques/T1548/002
# Webpage fetched successfully /techniques/T1548/003
# Webpage fetched successfully /techniques/T1548/004
# Webpage fetched successfully /techniques/T1548/005
# Webpage fetched successfully /techniques/T1548/006
# Webpage fetched successfully /techniques/T1134
# Webpage fetched successfully /techniques/T1134/001
# Webpage fetched successfully /techniques/T1134/002
# Webpage fetched successfully /techniques/T1134/003
# Webpage fetched successfully /techniques/T1134/004
# Webpage fetched successfully /techniques/T1134/005
# Webpage fetched successfully /techniques/T1197
# Webpage fetched successfully /techniques/T1612
# Webpage fetched successfully /techniques/T1622
# Webpage fetched successfully /techniques/T1140
# Webpage fetched successfully /techniques/T1610
# Webpage fetched successfully /techniques/T1006
# Webpage fetched successfully /techniques/T1484
# Webpage fetched successfully /techniques/T1484/001
# Webpage fetched successfully /techniques/T1484/002
# Webpage fetched successfully /techniques/T1480
# Webpage fetched successfully /techniques/T1480/001
# Webpage fetched successfully /techniques/T1211
# Webpage fetched successfully /techniques/T1222
# Webpage fetched successfully /techniques/T1222/001
# Webpage fetched successfully /techniques/T1222/002
# Webpage fetched successfully /techniques/T1564
# Webpage fetched successfully /techniques/T1564/001
# Webpage fetched successfully /techniques/T1564/002
# Webpage fetched successfully /techniques/T1564/003
# Webpage fetched successfully /techniques/T1564/004
# Webpage fetched successfully /techniques/T1564/005
# Webpage fetched successfully /techniques/T1564/006
# Webpage fetched successfully /techniques/T1564/007
# Webpage fetched successfully /techniques/T1564/008
# Webpage fetched successfully /techniques/T1564/009
# Webpage fetched successfully /techniques/T1564/010
# Webpage fetched successfully /techniques/T1564/011
# Webpage fetched successfully /techniques/T1564/012
# Webpage fetched successfully /techniques/T1574
# Webpage fetched successfully /techniques/T1574/001
# Webpage fetched successfully /techniques/T1574/002
# Webpage fetched successfully /techniques/T1574/004
# Webpage fetched successfully /techniques/T1574/005
# Webpage fetched successfully /techniques/T1574/006
# Webpage fetched successfully /techniques/T1574/007
# Webpage fetched successfully /techniques/T1574/008
# Webpage fetched successfully /techniques/T1574/009
# Webpage fetched successfully /techniques/T1574/010
# Webpage fetched successfully /techniques/T1574/011
# Webpage fetched successfully /techniques/T1574/012
# Webpage fetched successfully /techniques/T1574/013
# Webpage fetched successfully /techniques/T1574/014
# Webpage fetched successfully /techniques/T1562
# Webpage fetched successfully /techniques/T1562/001
# Webpage fetched successfully /techniques/T1562/002
# Webpage fetched successfully /techniques/T1562/003
# Webpage fetched successfully /techniques/T1562/004
# Webpage fetched successfully /techniques/T1562/006
# Webpage fetched successfully /techniques/T1562/007
# Webpage fetched successfully /techniques/T1562/008
# Webpage fetched successfully /techniques/T1562/009
# Webpage fetched successfully /techniques/T1562/010
# Webpage fetched successfully /techniques/T1562/011
# Webpage fetched successfully /techniques/T1562/012
# Webpage fetched successfully /techniques/T1656
# Webpage fetched successfully /techniques/T1070
# Webpage fetched successfully /techniques/T1070/001
# Webpage fetched successfully /techniques/T1070/002
# Webpage fetched successfully /techniques/T1070/003
# Webpage fetched successfully /techniques/T1070/004
# Webpage fetched successfully /techniques/T1070/005
# Webpage fetched successfully /techniques/T1070/006
# Webpage fetched successfully /techniques/T1070/007
# Webpage fetched successfully /techniques/T1070/008
# Webpage fetched successfully /techniques/T1070/009
# Webpage fetched successfully /techniques/T1202
# Webpage fetched successfully /techniques/T1036
# Webpage fetched successfully /techniques/T1036/001
# Webpage fetched successfully /techniques/T1036/002
# Webpage fetched successfully /techniques/T1036/003
# Webpage fetched successfully /techniques/T1036/004
# Webpage fetched successfully /techniques/T1036/005
# Webpage fetched successfully /techniques/T1036/006
# Webpage fetched successfully /techniques/T1036/007
# Webpage fetched successfully /techniques/T1036/008
# Webpage fetched successfully /techniques/T1036/009
# Webpage fetched successfully /techniques/T1556
# Webpage fetched successfully /techniques/T1556/001
# Webpage fetched successfully /techniques/T1556/002
# Webpage fetched successfully /techniques/T1556/003
# Webpage fetched successfully /techniques/T1556/004
# Webpage fetched successfully /techniques/T1556/005
# Webpage fetched successfully /techniques/T1556/006
# Webpage fetched successfully /techniques/T1556/007
# Webpage fetched successfully /techniques/T1556/008
# Webpage fetched successfully /techniques/T1556/009
# Webpage fetched successfully /techniques/T1578
# Webpage fetched successfully /techniques/T1578/001
# Webpage fetched successfully /techniques/T1578/002
# Webpage fetched successfully /techniques/T1578/003
# Webpage fetched successfully /techniques/T1578/004
# Webpage fetched successfully /techniques/T1578/005
# Webpage fetched successfully /techniques/T1112
# Webpage fetched successfully /techniques/T1601
# Webpage fetched successfully /techniques/T1601/001
# Webpage fetched successfully /techniques/T1601/002
# Webpage fetched successfully /techniques/T1599
# Webpage fetched successfully /techniques/T1599/001
# Webpage fetched successfully /techniques/T1027
# Webpage fetched successfully /techniques/T1027/001
# Webpage fetched successfully /techniques/T1027/002
# Webpage fetched successfully /techniques/T1027/003
# Webpage fetched successfully /techniques/T1027/004
# Webpage fetched successfully /techniques/T1027/005
# Webpage fetched successfully /techniques/T1027/006
# Webpage fetched successfully /techniques/T1027/007
# Webpage fetched successfully /techniques/T1027/008
# Webpage fetched successfully /techniques/T1027/009
# Webpage fetched successfully /techniques/T1027/010
# Webpage fetched successfully /techniques/T1027/011
# Webpage fetched successfully /techniques/T1027/012
# Webpage fetched successfully /techniques/T1027/013
# Webpage fetched successfully /techniques/T1647
# Webpage fetched successfully /techniques/T1542
# Webpage fetched successfully /techniques/T1542/001
# Webpage fetched successfully /techniques/T1542/002
# Webpage fetched successfully /techniques/T1542/003
# Webpage fetched successfully /techniques/T1542/004
# Webpage fetched successfully /techniques/T1542/005
# Webpage fetched successfully /techniques/T1055
# Webpage fetched successfully /techniques/T1055/001
# Webpage fetched successfully /techniques/T1055/002
# Webpage fetched successfully /techniques/T1055/003
# Webpage fetched successfully /techniques/T1055/004
# Webpage fetched successfully /techniques/T1055/005
# Webpage fetched successfully /techniques/T1055/008
# Webpage fetched successfully /techniques/T1055/009
# Webpage fetched successfully /techniques/T1055/011
# Webpage fetched successfully /techniques/T1055/012
# Webpage fetched successfully /techniques/T1055/013
# Webpage fetched successfully /techniques/T1055/014
# Webpage fetched successfully /techniques/T1055/015
# Webpage fetched successfully /techniques/T1620
# Webpage fetched successfully /techniques/T1207
# Webpage fetched successfully /techniques/T1014
# Webpage fetched successfully /techniques/T1553
# Webpage fetched successfully /techniques/T1553/001
# Webpage fetched successfully /techniques/T1553/002
# Webpage fetched successfully /techniques/T1553/003
# Webpage fetched successfully /techniques/T1553/004
# Webpage fetched successfully /techniques/T1553/005
# Webpage fetched successfully /techniques/T1553/006
# Webpage fetched successfully /techniques/T1218
# Webpage fetched successfully /techniques/T1218/001
# Webpage fetched successfully /techniques/T1218/002
# Webpage fetched successfully /techniques/T1218/003
# Webpage fetched successfully /techniques/T1218/004
# Webpage fetched successfully /techniques/T1218/005
# Webpage fetched successfully /techniques/T1218/007
# Webpage fetched successfully /techniques/T1218/008
# Webpage fetched successfully /techniques/T1218/009
# Webpage fetched successfully /techniques/T1218/010
# Webpage fetched successfully /techniques/T1218/011
# Webpage fetched successfully /techniques/T1218/012
# Webpage fetched successfully /techniques/T1218/013
# Webpage fetched successfully /techniques/T1218/014
# Webpage fetched successfully /techniques/T1218/015
# Webpage fetched successfully /techniques/T1216
# Webpage fetched successfully /techniques/T1216/001
# Webpage fetched successfully /techniques/T1216/002
# Webpage fetched successfully /techniques/T1221
# Webpage fetched successfully /techniques/T1205
# Webpage fetched successfully /techniques/T1205/001
# Webpage fetched successfully /techniques/T1205/002
# Webpage fetched successfully /techniques/T1127
# Webpage fetched successfully /techniques/T1127/001
# Webpage fetched successfully /techniques/T1535
# Webpage fetched successfully /techniques/T1550
# Webpage fetched successfully /techniques/T1550/001
# Webpage fetched successfully /techniques/T1550/002
# Webpage fetched successfully /techniques/T1550/003
# Webpage fetched successfully /techniques/T1550/004
# Webpage fetched successfully /techniques/T1078
# Webpage fetched successfully /techniques/T1078/001
# Webpage fetched successfully /techniques/T1078/002
# Webpage fetched successfully /techniques/T1078/003
# Webpage fetched successfully /techniques/T1078/004
# Webpage fetched successfully /techniques/T1497
# Webpage fetched successfully /techniques/T1497/001
# Webpage fetched successfully /techniques/T1497/002
# Webpage fetched successfully /techniques/T1497/003
# Webpage fetched successfully /techniques/T1600
# Webpage fetched successfully /techniques/T1600/001
# Webpage fetched successfully /techniques/T1600/002
# Webpage fetched successfully /techniques/T1220
# Webpage fetched successfully /techniques/T1557
# Webpage fetched successfully /techniques/T1557/001
# Webpage fetched successfully /techniques/T1557/002
# Webpage fetched successfully /techniques/T1557/003
# Webpage fetched successfully /techniques/T1110
# Webpage fetched successfully /techniques/T1110/001
# Webpage fetched successfully /techniques/T1110/002
# Webpage fetched successfully /techniques/T1110/003
# Webpage fetched successfully /techniques/T1110/004
# Webpage fetched successfully /techniques/T1555
# Webpage fetched successfully /techniques/T1555/001
# Webpage fetched successfully /techniques/T1555/002
# Webpage fetched successfully /techniques/T1555/003
# Webpage fetched successfully /techniques/T1555/004
# Webpage fetched successfully /techniques/T1555/005
# Webpage fetched successfully /techniques/T1555/006
# Webpage fetched successfully /techniques/T1212
# Webpage fetched successfully /techniques/T1187
# Webpage fetched successfully /techniques/T1606
# Webpage fetched successfully /techniques/T1606/001
# Webpage fetched successfully /techniques/T1606/002
# Webpage fetched successfully /techniques/T1056
# Webpage fetched successfully /techniques/T1056/001
# Webpage fetched successfully /techniques/T1056/002
# Webpage fetched successfully /techniques/T1056/003
# Webpage fetched successfully /techniques/T1056/004
# Webpage fetched successfully /techniques/T1556
# Webpage fetched successfully /techniques/T1556/001
# Webpage fetched successfully /techniques/T1556/002
# Webpage fetched successfully /techniques/T1556/003
# Webpage fetched successfully /techniques/T1556/004
# Webpage fetched successfully /techniques/T1556/005
# Webpage fetched successfully /techniques/T1556/006
# Webpage fetched successfully /techniques/T1556/007
# Webpage fetched successfully /techniques/T1556/008
# Webpage fetched successfully /techniques/T1556/009
# Webpage fetched successfully /techniques/T1111
# Webpage fetched successfully /techniques/T1621
# Webpage fetched successfully /techniques/T1040
# Webpage fetched successfully /techniques/T1003
# Webpage fetched successfully /techniques/T1003/001
# Webpage fetched successfully /techniques/T1003/002
# Webpage fetched successfully /techniques/T1003/003
# Webpage fetched successfully /techniques/T1003/004
# Webpage fetched successfully /techniques/T1003/005
# Webpage fetched successfully /techniques/T1003/006
# Webpage fetched successfully /techniques/T1003/007
# Webpage fetched successfully /techniques/T1003/008
# Webpage fetched successfully /techniques/T1528
# Webpage fetched successfully /techniques/T1649
# Webpage fetched successfully /techniques/T1558
# Webpage fetched successfully /techniques/T1558/001
# Webpage fetched successfully /techniques/T1558/002
# Webpage fetched successfully /techniques/T1558/003
# Webpage fetched successfully /techniques/T1558/004
# Webpage fetched successfully /techniques/T1539
# Webpage fetched successfully /techniques/T1552
# Webpage fetched successfully /techniques/T1552/001
# Webpage fetched successfully /techniques/T1552/002
# Webpage fetched successfully /techniques/T1552/003
# Webpage fetched successfully /techniques/T1552/004
# Webpage fetched successfully /techniques/T1552/005
# Webpage fetched successfully /techniques/T1552/006
# Webpage fetched successfully /techniques/T1552/007
# Webpage fetched successfully /techniques/T1552/008
# Webpage fetched successfully /techniques/T1087
# Webpage fetched successfully /techniques/T1087/001
# Webpage fetched successfully /techniques/T1087/002
# Webpage fetched successfully /techniques/T1087/003
# Webpage fetched successfully /techniques/T1087/004
# Webpage fetched successfully /techniques/T1010
# Webpage fetched successfully /techniques/T1217
# Webpage fetched successfully /techniques/T1580
# Webpage fetched successfully /techniques/T1538
# Webpage fetched successfully /techniques/T1526
# Webpage fetched successfully /techniques/T1619
# Webpage fetched successfully /techniques/T1613
# Webpage fetched successfully /techniques/T1622
# Webpage fetched successfully /techniques/T1652
# Webpage fetched successfully /techniques/T1482
# Webpage fetched successfully /techniques/T1083
# Webpage fetched successfully /techniques/T1615
# Webpage fetched successfully /techniques/T1654
# Webpage fetched successfully /techniques/T1046
# Webpage fetched successfully /techniques/T1135
# Webpage fetched successfully /techniques/T1040
# Webpage fetched successfully /techniques/T1201
# Webpage fetched successfully /techniques/T1120
# Webpage fetched successfully /techniques/T1069
# Webpage fetched successfully /techniques/T1069/001
# Webpage fetched successfully /techniques/T1069/002
# Webpage fetched successfully /techniques/T1069/003
# Webpage fetched successfully /techniques/T1057
# Webpage fetched successfully /techniques/T1012
# Webpage fetched successfully /techniques/T1018
# Webpage fetched successfully /techniques/T1518
# Webpage fetched successfully /techniques/T1518/001
# Webpage fetched successfully /techniques/T1082
# Webpage fetched successfully /techniques/T1614
# Webpage fetched successfully /techniques/T1614/001
# Webpage fetched successfully /techniques/T1016
# Webpage fetched successfully /techniques/T1016/001
# Webpage fetched successfully /techniques/T1016/002
# Webpage fetched successfully /techniques/T1049
# Webpage fetched successfully /techniques/T1033
# Webpage fetched successfully /techniques/T1007
# Webpage fetched successfully /techniques/T1124
# Webpage fetched successfully /techniques/T1497
# Webpage fetched successfully /techniques/T1497/001
# Webpage fetched successfully /techniques/T1497/002
# Webpage fetched successfully /techniques/T1497/003
# Webpage fetched successfully /techniques/T1210
# Webpage fetched successfully /techniques/T1534
# Webpage fetched successfully /techniques/T1570
# Webpage fetched successfully /techniques/T1563
# Webpage fetched successfully /techniques/T1563/001
# Webpage fetched successfully /techniques/T1563/002
# Webpage fetched successfully /techniques/T1021
# Webpage fetched successfully /techniques/T1021/001
# Webpage fetched successfully /techniques/T1021/002
# Webpage fetched successfully /techniques/T1021/003
# Webpage fetched successfully /techniques/T1021/004
# Webpage fetched successfully /techniques/T1021/005
# Webpage fetched successfully /techniques/T1021/006
# Webpage fetched successfully /techniques/T1021/007
# Webpage fetched successfully /techniques/T1021/008
# Webpage fetched successfully /techniques/T1091
# Webpage fetched successfully /techniques/T1072
# Webpage fetched successfully /techniques/T1080
# Webpage fetched successfully /techniques/T1550
# Webpage fetched successfully /techniques/T1550/001
# Webpage fetched successfully /techniques/T1550/002
# Webpage fetched successfully /techniques/T1550/003
# Webpage fetched successfully /techniques/T1550/004
# Webpage fetched successfully /techniques/T1557
# Webpage fetched successfully /techniques/T1557/001
# Webpage fetched successfully /techniques/T1557/002
# Webpage fetched successfully /techniques/T1557/003
# Webpage fetched successfully /techniques/T1560
# Webpage fetched successfully /techniques/T1560/001
# Webpage fetched successfully /techniques/T1560/002
# Webpage fetched successfully /techniques/T1560/003
# Webpage fetched successfully /techniques/T1123
# Webpage fetched successfully /techniques/T1119
# Webpage fetched successfully /techniques/T1185
# Webpage fetched successfully /techniques/T1115
# Webpage fetched successfully /techniques/T1530
# Webpage fetched successfully /techniques/T1602
# Webpage fetched successfully /techniques/T1602/001
# Webpage fetched successfully /techniques/T1602/002
# Webpage fetched successfully /techniques/T1213
# Webpage fetched successfully /techniques/T1213/001
# Webpage fetched successfully /techniques/T1213/002
# Webpage fetched successfully /techniques/T1213/003
# Webpage fetched successfully /techniques/T1005
# Webpage fetched successfully /techniques/T1039
# Webpage fetched successfully /techniques/T1025
# Webpage fetched successfully /techniques/T1074
# Webpage fetched successfully /techniques/T1074/001
# Webpage fetched successfully /techniques/T1074/002
# Webpage fetched successfully /techniques/T1114
# Webpage fetched successfully /techniques/T1114/001
# Webpage fetched successfully /techniques/T1114/002
# Webpage fetched successfully /techniques/T1114/003
# Webpage fetched successfully /techniques/T1056
# Webpage fetched successfully /techniques/T1056/001
# Webpage fetched successfully /techniques/T1056/002
# Webpage fetched successfully /techniques/T1056/003
# Webpage fetched successfully /techniques/T1056/004
# Webpage fetched successfully /techniques/T1113
# Webpage fetched successfully /techniques/T1125
# Webpage fetched successfully /techniques/T1071
# Webpage fetched successfully /techniques/T1071/001
# Webpage fetched successfully /techniques/T1071/002
# Webpage fetched successfully /techniques/T1071/003
# Webpage fetched successfully /techniques/T1071/004
# Webpage fetched successfully /techniques/T1092
# Webpage fetched successfully /techniques/T1659
# Webpage fetched successfully /techniques/T1132
# Webpage fetched successfully /techniques/T1132/001
# Webpage fetched successfully /techniques/T1132/002
# Webpage fetched successfully /techniques/T1001
# Webpage fetched successfully /techniques/T1001/001
# Webpage fetched successfully /techniques/T1001/002
# Webpage fetched successfully /techniques/T1001/003
# Webpage fetched successfully /techniques/T1568
# Webpage fetched successfully /techniques/T1568/001
# Webpage fetched successfully /techniques/T1568/002
# Webpage fetched successfully /techniques/T1568/003
# Webpage fetched successfully /techniques/T1573
# Webpage fetched successfully /techniques/T1573/001
# Webpage fetched successfully /techniques/T1573/002
# Webpage fetched successfully /techniques/T1008
# Webpage fetched successfully /techniques/T1665
# Webpage fetched successfully /techniques/T1105
# Webpage fetched successfully /techniques/T1104
# Webpage fetched successfully /techniques/T1095
# Webpage fetched successfully /techniques/T1571
# Webpage fetched successfully /techniques/T1572
# Webpage fetched successfully /techniques/T1090
# Webpage fetched successfully /techniques/T1090/001
# Webpage fetched successfully /techniques/T1090/002
# Webpage fetched successfully /techniques/T1090/003
# Webpage fetched successfully /techniques/T1090/004
# Webpage fetched successfully /techniques/T1219
# Webpage fetched successfully /techniques/T1205
# Webpage fetched successfully /techniques/T1205/001
# Webpage fetched successfully /techniques/T1205/002
# Webpage fetched successfully /techniques/T1102
# Webpage fetched successfully /techniques/T1102/001
# Webpage fetched successfully /techniques/T1102/002
# Webpage fetched successfully /techniques/T1102/003
# Webpage fetched successfully /techniques/T1020
# Webpage fetched successfully /techniques/T1020/001
# Webpage fetched successfully /techniques/T1030
# Webpage fetched successfully /techniques/T1048
# Webpage fetched successfully /techniques/T1048/001
# Webpage fetched successfully /techniques/T1048/002
# Webpage fetched successfully /techniques/T1048/003
# Webpage fetched successfully /techniques/T1041
# Webpage fetched successfully /techniques/T1011
# Webpage fetched successfully /techniques/T1011/001
# Webpage fetched successfully /techniques/T1052
# Webpage fetched successfully /techniques/T1052/001
# Webpage fetched successfully /techniques/T1567
# Webpage fetched successfully /techniques/T1567/001
# Webpage fetched successfully /techniques/T1567/002
# Webpage fetched successfully /techniques/T1567/003
# Webpage fetched successfully /techniques/T1567/004
# Webpage fetched successfully /techniques/T1029
# Webpage fetched successfully /techniques/T1537
# Webpage fetched successfully /techniques/T1531
# Webpage fetched successfully /techniques/T1485
# Webpage fetched successfully /techniques/T1486
# Webpage fetched successfully /techniques/T1565
# Webpage fetched successfully /techniques/T1565/001
# Webpage fetched successfully /techniques/T1565/002
# Webpage fetched successfully /techniques/T1565/003
# Webpage fetched successfully /techniques/T1491
# Webpage fetched successfully /techniques/T1491/001
# Webpage fetched successfully /techniques/T1491/002
# Webpage fetched successfully /techniques/T1561
# Webpage fetched successfully /techniques/T1561/001
# Webpage fetched successfully /techniques/T1561/002
# Webpage fetched successfully /techniques/T1499
# Webpage fetched successfully /techniques/T1499/001
# Webpage fetched successfully /techniques/T1499/002
# Webpage fetched successfully /techniques/T1499/003
# Webpage fetched successfully /techniques/T1499/004
# Webpage fetched successfully /techniques/T1657
# Webpage fetched successfully /techniques/T1495
# Webpage fetched successfully /techniques/T1490
# Webpage fetched successfully /techniques/T1498
# Webpage fetched successfully /techniques/T1498/001
# Webpage fetched successfully /techniques/T1498/002
# Webpage fetched successfully /techniques/T1496
# Webpage fetched successfully /techniques/T1489
# Webpage fetched successfully /techniques/T1529
# Webpage fetched successfully /techniques/T1595
# Webpage fetched successfully /techniques/T1595/001
# Webpage fetched successfully /techniques/T1595/002
# Webpage fetched successfully /techniques/T1595/003
# Webpage fetched successfully /techniques/T1592
# Webpage fetched successfully /techniques/T1592/001
# Webpage fetched successfully /techniques/T1592/002
# Webpage fetched successfully /techniques/T1592/003
# Webpage fetched successfully /techniques/T1592/004
# Webpage fetched successfully /techniques/T1589
# Webpage fetched successfully /techniques/T1589/001
# Webpage fetched successfully /techniques/T1589/002
# Webpage fetched successfully /techniques/T1589/003
# Webpage fetched successfully /techniques/T1590
# Webpage fetched successfully /techniques/T1590/001
# Webpage fetched successfully /techniques/T1590/002
# Webpage fetched successfully /techniques/T1590/003
# Webpage fetched successfully /techniques/T1590/004
# Webpage fetched successfully /techniques/T1590/005
# Webpage fetched successfully /techniques/T1590/006
# Webpage fetched successfully /techniques/T1591
# Webpage fetched successfully /techniques/T1591/001
# Webpage fetched successfully /techniques/T1591/002
# Webpage fetched successfully /techniques/T1591/003
# Webpage fetched successfully /techniques/T1591/004
# Webpage fetched successfully /techniques/T1598
# Webpage fetched successfully /techniques/T1598/001
# Webpage fetched successfully /techniques/T1598/002
# Webpage fetched successfully /techniques/T1598/003
# Webpage fetched successfully /techniques/T1598/004
# Webpage fetched successfully /techniques/T1597
# Webpage fetched successfully /techniques/T1597/001
# Webpage fetched successfully /techniques/T1597/002
# Webpage fetched successfully /techniques/T1596
# Webpage fetched successfully /techniques/T1596/001
# Webpage fetched successfully /techniques/T1596/002
# Webpage fetched successfully /techniques/T1596/003
# Webpage fetched successfully /techniques/T1596/004
# Webpage fetched successfully /techniques/T1596/005
# Webpage fetched successfully /techniques/T1593
# Webpage fetched successfully /techniques/T1593/001
# Webpage fetched successfully /techniques/T1593/002
# Webpage fetched successfully /techniques/T1593/003
# Webpage fetched successfully /techniques/T1594
# Webpage fetched successfully /techniques/T1650
# Webpage fetched successfully /techniques/T1583
# Webpage fetched successfully /techniques/T1583/001
# Webpage fetched successfully /techniques/T1583/002
# Webpage fetched successfully /techniques/T1583/003
# Webpage fetched successfully /techniques/T1583/004
# Webpage fetched successfully /techniques/T1583/005
# Webpage fetched successfully /techniques/T1583/006
# Webpage fetched successfully /techniques/T1583/007
# Webpage fetched successfully /techniques/T1583/008
# Webpage fetched successfully /techniques/T1586
# Webpage fetched successfully /techniques/T1586/001
# Webpage fetched successfully /techniques/T1586/002
# Webpage fetched successfully /techniques/T1586/003
# Webpage fetched successfully /techniques/T1584
# Webpage fetched successfully /techniques/T1584/001
# Webpage fetched successfully /techniques/T1584/002
# Webpage fetched successfully /techniques/T1584/003
# Webpage fetched successfully /techniques/T1584/004
# Webpage fetched successfully /techniques/T1584/005
# Webpage fetched successfully /techniques/T1584/006
# Webpage fetched successfully /techniques/T1584/007
# Webpage fetched successfully /techniques/T1584/008
# Webpage fetched successfully /techniques/T1587
# Webpage fetched successfully /techniques/T1587/001
# Webpage fetched successfully /techniques/T1587/002
# Webpage fetched successfully /techniques/T1587/003
# Webpage fetched successfully /techniques/T1587/004
# Webpage fetched successfully /techniques/T1585
# Webpage fetched successfully /techniques/T1585/001
# Webpage fetched successfully /techniques/T1585/002
# Webpage fetched successfully /techniques/T1585/003
# Webpage fetched successfully /techniques/T1588
# Webpage fetched successfully /techniques/T1588/001
# Webpage fetched successfully /techniques/T1588/002
# Webpage fetched successfully /techniques/T1588/003
# Webpage fetched successfully /techniques/T1588/004
# Webpage fetched successfully /techniques/T1588/005
# Webpage fetched successfully /techniques/T1588/006
# Webpage fetched successfully /techniques/T1588/007
# Webpage fetched successfully /techniques/T1608
# Webpage fetched successfully /techniques/T1608/001
# Webpage fetched successfully /techniques/T1608/002
# Webpage fetched successfully /techniques/T1608/003
# Webpage fetched successfully /techniques/T1608/004
# Webpage fetched successfully /techniques/T1608/005
# Webpage fetched successfully /techniques/T1608/006
# Webpage fetched successfully /techniques/T1659
# Webpage fetched successfully /techniques/T1189
# Webpage fetched successfully /techniques/T1190
# Webpage fetched successfully /techniques/T1133
# Webpage fetched successfully /techniques/T1200
# Webpage fetched successfully /techniques/T1566
# Webpage fetched successfully /techniques/T1566/001
# Webpage fetched successfully /techniques/T1566/002
# Webpage fetched successfully /techniques/T1566/003
# Webpage fetched successfully /techniques/T1566/004
# Webpage fetched successfully /techniques/T1091
# Webpage fetched successfully /techniques/T1195
# Webpage fetched successfully /techniques/T1195/001
# Webpage fetched successfully /techniques/T1195/002
# Webpage fetched successfully /techniques/T1195/003
# Webpage fetched successfully /techniques/T1199
# Webpage fetched successfully /techniques/T1078
# Webpage fetched successfully /techniques/T1078/001
# Webpage fetched successfully /techniques/T1078/002
# Webpage fetched successfully /techniques/T1078/003
# Webpage fetched successfully /techniques/T1078/004
# Webpage fetched successfully /techniques/T1651
# Webpage fetched successfully /techniques/T1059
# Webpage fetched successfully /techniques/T1059/001
# Webpage fetched successfully /techniques/T1059/002
# Webpage fetched successfully /techniques/T1059/003
# Webpage fetched successfully /techniques/T1059/004
# Webpage fetched successfully /techniques/T1059/005
# Webpage fetched successfully /techniques/T1059/006
# Webpage fetched successfully /techniques/T1059/007
# Webpage fetched successfully /techniques/T1059/008
# Webpage fetched successfully /techniques/T1059/009
# Webpage fetched successfully /techniques/T1059/010
# Webpage fetched successfully /techniques/T1609
# Webpage fetched successfully /techniques/T1610
# Webpage fetched successfully /techniques/T1203
# Webpage fetched successfully /techniques/T1559
# Webpage fetched successfully /techniques/T1559/001
# Webpage fetched successfully /techniques/T1559/002
# Webpage fetched successfully /techniques/T1559/003
# Webpage fetched successfully /techniques/T1106
# ...
# Webpage fetched successfully /techniques/T1574
# Webpage fetched successfully /techniques/T1574/001
# Webpage fetched successfully /techniques/T1574/002
# Webpage fetched successfully /techniques/T1574/004
# Webpage fetched successfully /techniques/T1574/005
# Webpage fetched successfully /techniques/T1574/006
# Webpage fetched successfully /techniques/T1574/007
# Webpage fetched successfully /techniques/T1574/008
# Webpage fetched successfully /techniques/T1574/009
# Webpage fetched successfully /techniques/T1574/010
# Webpage fetched successfully /techniques/T1574/011
# Webpage fetched successfully /techniques/T1574/012
# Webpage fetched successfully /techniques/T1574/013
# Webpage fetched successfully /techniques/T1574/014
# Webpage fetched successfully /techniques/T1562
# Webpage fetched successfully /techniques/T1562/001
# Webpage fetched successfully /techniques/T1562/002
# Webpage fetched successfully /techniques/T1562/003
# Webpage fetched successfully /techniques/T1562/004
# Webpage fetched successfully /techniques/T1562/006
# Webpage fetched successfully /techniques/T1562/007
# Webpage fetched successfully /techniques/T1562/008
# Webpage fetched successfully /techniques/T1562/009
# Webpage fetched successfully /techniques/T1562/010
# Webpage fetched successfully /techniques/T1562/011
# Webpage fetched successfully /techniques/T1562/012
# Webpage fetched successfully /techniques/T1656
# Webpage fetched successfully /techniques/T1070
# Webpage fetched successfully /techniques/T1070/001
# Webpage fetched successfully /techniques/T1070/002
# Webpage fetched successfully /techniques/T1070/003
# Webpage fetched successfully /techniques/T1070/004
# Webpage fetched successfully /techniques/T1070/005
# Webpage fetched successfully /techniques/T1070/006
# Webpage fetched successfully /techniques/T1070/007
# Webpage fetched successfully /techniques/T1070/008
# Webpage fetched successfully /techniques/T1070/009
# Webpage fetched successfully /techniques/T1202
# Webpage fetched successfully /techniques/T1036
# Webpage fetched successfully /techniques/T1036/001
# Webpage fetched successfully /techniques/T1036/002
# Webpage fetched successfully /techniques/T1036/003
# Webpage fetched successfully /techniques/T1036/004
# Webpage fetched successfully /techniques/T1036/005
# Webpage fetched successfully /techniques/T1036/006
# Webpage fetched successfully /techniques/T1036/007
# Webpage fetched successfully /techniques/T1036/008
# Webpage fetched successfully /techniques/T1036/009
# Webpage fetched successfully /techniques/T1556
# Webpage fetched successfully /techniques/T1556/001
# Webpage fetched successfully /techniques/T1556/002
# Webpage fetched successfully /techniques/T1556/003
# Webpage fetched successfully /techniques/T1556/004
# Webpage fetched successfully /techniques/T1556/005
# Webpage fetched successfully /techniques/T1556/006
# Webpage fetched successfully /techniques/T1556/007
# Webpage fetched successfully /techniques/T1556/008
# Webpage fetched successfully /techniques/T1556/009
# Webpage fetched successfully /techniques/T1578
# Webpage fetched successfully /techniques/T1578/001
# Webpage fetched successfully /techniques/T1578/002
# Webpage fetched successfully /techniques/T1578/003
# Webpage fetched successfully /techniques/T1578/004
# Webpage fetched successfully /techniques/T1578/005
# Webpage fetched successfully /techniques/T1112
# Webpage fetched successfully /techniques/T1601
# Webpage fetched successfully /techniques/T1601/001
# Webpage fetched successfully /techniques/T1601/002
# Webpage fetched successfully /techniques/T1599
# Webpage fetched successfully /techniques/T1599/001
# Webpage fetched successfully /techniques/T1027
# Webpage fetched successfully /techniques/T1027/001
# Webpage fetched successfully /techniques/T1027/002
# Webpage fetched successfully /techniques/T1027/003
# Webpage fetched successfully /techniques/T1027/004
# Webpage fetched successfully /techniques/T1027/005
# Webpage fetched successfully /techniques/T1027/006
# Webpage fetched successfully /techniques/T1027/007
# Webpage fetched successfully /techniques/T1027/008
# Webpage fetched successfully /techniques/T1027/009
# Webpage fetched successfully /techniques/T1027/010
# Webpage fetched successfully /techniques/T1027/011
# Webpage fetched successfully /techniques/T1027/012
# Webpage fetched successfully /techniques/T1027/013
# Webpage fetched successfully /techniques/T1647
# Webpage fetched successfully /techniques/T1542
# Webpage fetched successfully /techniques/T1542/001
# Webpage fetched successfully /techniques/T1542/002
# Webpage fetched successfully /techniques/T1542/003
# Webpage fetched successfully /techniques/T1542/004
# Webpage fetched successfully /techniques/T1542/005
# Webpage fetched successfully /techniques/T1055
# Webpage fetched successfully /techniques/T1055/001
# Webpage fetched successfully /techniques/T1055/002
# Webpage fetched successfully /techniques/T1055/003
# Webpage fetched successfully /techniques/T1055/004
# Webpage fetched successfully /techniques/T1055/005
# Webpage fetched successfully /techniques/T1055/008
# Webpage fetched successfully /techniques/T1055/009
# Webpage fetched successfully /techniques/T1055/011
# Webpage fetched successfully /techniques/T1055/012
# Webpage fetched successfully /techniques/T1055/013
# Webpage fetched successfully /techniques/T1055/014
# Webpage fetched successfully /techniques/T1055/015
# Webpage fetched successfully /techniques/T1620
# Webpage fetched successfully /techniques/T1207
# Webpage fetched successfully /techniques/T1014
# Webpage fetched successfully /techniques/T1553
# Webpage fetched successfully /techniques/T1553/001
# Webpage fetched successfully /techniques/T1553/002
# Webpage fetched successfully /techniques/T1553/003
# Webpage fetched successfully /techniques/T1553/004
# Webpage fetched successfully /techniques/T1553/005
# Webpage fetched successfully /techniques/T1553/006
# Webpage fetched successfully /techniques/T1218
# Webpage fetched successfully /techniques/T1218/001
# Webpage fetched successfully /techniques/T1218/002
# Webpage fetched successfully /techniques/T1218/003
# Webpage fetched successfully /techniques/T1218/004
# Webpage fetched successfully /techniques/T1218/005
# Webpage fetched successfully /techniques/T1218/007
# Webpage fetched successfully /techniques/T1218/008
# Webpage fetched successfully /techniques/T1218/009
# Webpage fetched successfully /techniques/T1218/010
# Webpage fetched successfully /techniques/T1218/011
# Webpage fetched successfully /techniques/T1218/012
# Webpage fetched successfully /techniques/T1218/013
# Webpage fetched successfully /techniques/T1218/014
# Webpage fetched successfully /techniques/T1218/015
# Webpage fetched successfully /techniques/T1216
# Webpage fetched successfully /techniques/T1216/001
# Webpage fetched successfully /techniques/T1216/002
# Webpage fetched successfully /techniques/T1221
# Webpage fetched successfully /techniques/T1205
# Webpage fetched successfully /techniques/T1205/001
# Webpage fetched successfully /techniques/T1205/002
# Webpage fetched successfully /techniques/T1127
# Webpage fetched successfully /techniques/T1127/001
# Webpage fetched successfully /techniques/T1535
# Webpage fetched successfully /techniques/T1550
# Webpage fetched successfully /techniques/T1550/001
# Webpage fetched successfully /techniques/T1550/002
# Webpage fetched successfully /techniques/T1550/003
# Webpage fetched successfully /techniques/T1550/004
# Webpage fetched successfully /techniques/T1078
# Webpage fetched successfully /techniques/T1078/001
# Webpage fetched successfully /techniques/T1078/002
# Webpage fetched successfully /techniques/T1078/003
# Webpage fetched successfully /techniques/T1078/004
# Webpage fetched successfully /techniques/T1497
# Webpage fetched successfully /techniques/T1497/001
# Webpage fetched successfully /techniques/T1497/002
# Webpage fetched successfully /techniques/T1497/003
# Webpage fetched successfully /techniques/T1600
# Webpage fetched successfully /techniques/T1600/001
# Webpage fetched successfully /techniques/T1600/002
# Webpage fetched successfully /techniques/T1220
# Webpage fetched successfully /techniques/T1557
# Webpage fetched successfully /techniques/T1557/001
# Webpage fetched successfully /techniques/T1557/002
# Webpage fetched successfully /techniques/T1557/003
# Webpage fetched successfully /techniques/T1110
# Webpage fetched successfully /techniques/T1110/001
# Webpage fetched successfully /techniques/T1110/002
# Webpage fetched successfully /techniques/T1110/003
# Webpage fetched successfully /techniques/T1110/004
# Webpage fetched successfully /techniques/T1555
# Webpage fetched successfully /techniques/T1555/001
# Webpage fetched successfully /techniques/T1555/002
# Webpage fetched successfully /techniques/T1555/003
# Webpage fetched successfully /techniques/T1555/004
# Webpage fetched successfully /techniques/T1555/005
# Webpage fetched successfully /techniques/T1555/006
# Webpage fetched successfully /techniques/T1212
# Webpage fetched successfully /techniques/T1187
# Webpage fetched successfully /techniques/T1606
# Webpage fetched successfully /techniques/T1606/001
# Webpage fetched successfully /techniques/T1606/002
# Webpage fetched successfully /techniques/T1056
# Webpage fetched successfully /techniques/T1056/001
# Webpage fetched successfully /techniques/T1056/002
# Webpage fetched successfully /techniques/T1056/003
# Webpage fetched successfully /techniques/T1056/004
# Webpage fetched successfully /techniques/T1556
# Webpage fetched successfully /techniques/T1556/001
# Webpage fetched successfully /techniques/T1556/002
# Webpage fetched successfully /techniques/T1556/003
# Webpage fetched successfully /techniques/T1556/004
# Webpage fetched successfully /techniques/T1556/005
# Webpage fetched successfully /techniques/T1556/006
# Webpage fetched successfully /techniques/T1556/007
# Webpage fetched successfully /techniques/T1556/008
# Webpage fetched successfully /techniques/T1556/009
# Webpage fetched successfully /techniques/T1111
# Webpage fetched successfully /techniques/T1621
# Webpage fetched successfully /techniques/T1040
# Webpage fetched successfully /techniques/T1003
# Webpage fetched successfully /techniques/T1003/001
# Webpage fetched successfully /techniques/T1003/002
# Webpage fetched successfully /techniques/T1003/003
# Webpage fetched successfully /techniques/T1003/004
# Webpage fetched successfully /techniques/T1003/005
# Webpage fetched successfully /techniques/T1003/006
# Webpage fetched successfully /techniques/T1003/007
# Webpage fetched successfully /techniques/T1003/008
# Webpage fetched successfully /techniques/T1528
# Webpage fetched successfully /techniques/T1649
# Webpage fetched successfully /techniques/T1558
# Webpage fetched successfully /techniques/T1558/001
# Webpage fetched successfully /techniques/T1558/002
# Webpage fetched successfully /techniques/T1558/003
# Webpage fetched successfully /techniques/T1558/004
# Webpage fetched successfully /techniques/T1539
# Webpage fetched successfully /techniques/T1552
# Webpage fetched successfully /techniques/T1552/001
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\grpc_helpers.py:75, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      74 try:
# ---> 75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\grpc\_channel.py:1176, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1170 (
#    1171     state,
#    1172     call,
#    1173 ) = self._blocking(
#    1174     request, timeout, metadata, credentials, wait_for_ready, compression
#    1175 )
# -> 1176 return _end_unary_response_blocking(state, call, False, None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\grpc\_channel.py:1005, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1004 else:
# -> 1005     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.RESOURCE_EXHAUSTED
# 	details = "Resource has been exhausted (e.g. check quota)."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:142.250.200.202:443 {created_time:"2024-07-29T09:39:53.6823167+00:00", grpc_status:8, grpc_message:"Resource has been exhausted (e.g. check quota)."}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[17], line 98
#      71     continue
#      73 prompt = """You are a cybersecurity expert specializing in cyber threat intelligence. Given the text below, please generate a maximum of 5 multiple-choice questions with four possible options each.
#      74
#      75 Follow these requirements:
#    (...)
#      95
#      96 """ + paragraphe + str(res)
# ---> 98 response = model.generate_content(prompt)
#     100 try:
#     101     with open('cti_mcq_generated.tsv', 'a') as file:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:827, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     824 self._validate_universe_domain()
#     826 # Send the request.
# --> 827 response = rpc(
#     828     request,
#     829     retry=retry,
#     830     timeout=timeout,
#     831     metadata=metadata,
#     832 )
#     834 # Done; return the response.
#     835 return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry.py:372, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     368 target = functools.partial(func, *args, **kwargs)
#     369 sleep_generator = exponential_sleep_generator(
#     370     self._initial, self._maximum, multiplier=self._multiplier
#     371 )
# --> 372 return retry_target(
#     373     target,
#     374     self._predicate,
#     375     sleep_generator,
#     376     self._timeout,
#     377     on_error=on_error,
#     378 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry.py:207, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     205 for sleep in sleep_generator:
#     206     try:
# --> 207         result = target()
#     208         if inspect.isawaitable(result):
#     209             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).

# %% [markdown]
# # CTI-RCM

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import random


nb = 0
try:
    with open('cti_rcm_generated.tsv', 'a') as file:
        file.write('URL'+'\t'+'Description'+'\t'+'Prompt'+'\t'+'GT'+'\n')
        while nb < 1500:
            year = random.choice([2023, 2024])
            sub_url = random.randint(1000, 500000)
            # URL of the website
            url = 'https://nvd.nist.gov/vuln/detail/CVE-'+str(year)+'-'+str(sub_url)+'/'
            
            # Fetch the webpage
            response = requests.get(url)
            
            # Check if the request was successful
            if response.status_code == 200:
                try:
                    webpage_content = response.text
                    print('Webpage fetched successfully', year, sub_url)
                
                    # Parse the HTML content using BeautifulSoup
                    soup = BeautifulSoup(webpage_content, 'html.parser')
            
                    vuln_description = soup.find('p', {'data-testid': 'vuln-description'})
            
                    vuln_cwes_link = soup.find('td', {'data-testid': 'vuln-CWEs-link-0'})
            
                    if vuln_description and vuln_cwes_link:
                        description_text = vuln_description.get_text()
                        cwes_text = vuln_cwes_link.get_text()
                        if "-noinfo" not in cwes_text and 'CWE-' in cwes_text:
                            #print(description_text, cwes_text)
                            prompt = "Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:" + description_text
                            file.write(url.replace('\n', '') + '\t' + description_text.replace('\n', '') + '\t' + prompt.replace('\n', '') + '\t' + cwes_text.replace('\n', '') + '\n')
                            nb += 1
                            print(url.replace('\n', '') + '\t' + description_text.replace('\n', '') + '\t' + prompt.replace('\n', '') + '\t' + cwes_text.replace('\n', '') + str(nb) + '\n')
                except:
                    continue
                    
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Webpage fetched successfully 2024 169041
# Webpage fetched successfully 2024 38198
# Webpage fetched successfully 2024 344575
# Webpage fetched successfully 2024 41769
# Webpage fetched successfully 2023 285099
# Webpage fetched successfully 2024 270165
# Webpage fetched successfully 2023 422106
# Webpage fetched successfully 2023 203901
# Webpage fetched successfully 2023 442166
# Webpage fetched successfully 2024 167604
# Webpage fetched successfully 2023 243302
# Webpage fetched successfully 2024 138646
# Webpage fetched successfully 2024 294792
# Webpage fetched successfully 2024 325268
# Webpage fetched successfully 2024 406209
# Webpage fetched successfully 2024 195460
# Webpage fetched successfully 2023 473165
# Webpage fetched successfully 2023 250616
# Webpage fetched successfully 2023 129663
# Webpage fetched successfully 2023 320592
# Webpage fetched successfully 2024 196263
# Webpage fetched successfully 2024 132201
# Webpage fetched successfully 2024 320369
# Webpage fetched successfully 2024 191529
# Webpage fetched successfully 2023 496725
# Webpage fetched successfully 2024 114902
# Webpage fetched successfully 2024 474390
# Webpage fetched successfully 2023 323892
# Webpage fetched successfully 2023 73778
# Webpage fetched successfully 2024 173219
# Webpage fetched successfully 2023 451542
# Webpage fetched successfully 2023 413671
# Webpage fetched successfully 2023 370539
# Webpage fetched successfully 2023 147365
# Webpage fetched successfully 2023 207365
# Webpage fetched successfully 2024 35230
# Webpage fetched successfully 2023 399692
# Webpage fetched successfully 2023 2950
# https://nvd.nist.gov/vuln/detail/CVE-2023-2950/	Improper Authorization in GitHub repository openemr/openemr prior to 7.0.1.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Improper Authorization in GitHub repository openemr/openemr prior to 7.0.1.	CWE-2851
#
# Webpage fetched successfully 2024 83139
# Webpage fetched successfully 2024 346756
# Webpage fetched successfully 2024 353952
# Webpage fetched successfully 2023 362179
# Webpage fetched successfully 2024 443860
# Webpage fetched successfully 2024 338913
# Webpage fetched successfully 2023 124867
# Webpage fetched successfully 2024 241137
# Webpage fetched successfully 2024 29515
# Webpage fetched successfully 2024 267127
# Webpage fetched successfully 2024 374908
# Webpage fetched successfully 2023 299142
# Webpage fetched successfully 2023 153666
# Webpage fetched successfully 2024 306640
# Webpage fetched successfully 2023 275085
# Webpage fetched successfully 2024 311175
# Webpage fetched successfully 2023 404375
# Webpage fetched successfully 2023 268030
# Webpage fetched successfully 2023 67043
# Webpage fetched successfully 2023 178083
# Webpage fetched successfully 2024 159099
# Webpage fetched successfully 2023 454407
# Webpage fetched successfully 2023 489064
# Webpage fetched successfully 2023 124043
# Webpage fetched successfully 2023 9451
# Webpage fetched successfully 2023 83689
# Webpage fetched successfully 2024 331307
# Webpage fetched successfully 2024 167159
# Webpage fetched successfully 2023 216477
# Webpage fetched successfully 2023 95925
# Webpage fetched successfully 2023 119678
# Webpage fetched successfully 2023 47119
# https://nvd.nist.gov/vuln/detail/CVE-2023-47119/	Discourse is an open source platform for community discussion. Prior to version 3.1.3 of the `stable` branch and version 3.2.0.beta3 of the `beta` and `tests-passed` branches, some links can inject arbitrary HTML tags when rendered through our Onebox engine. The issue is patched in version 3.1.3 of the `stable` branch and version 3.2.0.beta3 of the `beta` and `tests-passed` branches. There are no known workarounds.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Discourse is an open source platform for community discussion. Prior to version 3.1.3 of the `stable` branch and version 3.2.0.beta3 of the `beta` and `tests-passed` branches, some links can inject arbitrary HTML tags when rendered through our Onebox engine. The issue is patched in version 3.1.3 of the `stable` branch and version 3.2.0.beta3 of the `beta` and `tests-passed` branches. There are no known workarounds.	CWE-792
#
# Webpage fetched successfully 2023 324337
# Webpage fetched successfully 2023 485548
# Webpage fetched successfully 2024 229639
# Webpage fetched successfully 2023 290203
# Webpage fetched successfully 2023 117862
# Webpage fetched successfully 2023 125921
# Webpage fetched successfully 2024 182203
# Webpage fetched successfully 2023 188850
# Webpage fetched successfully 2024 165367
# Webpage fetched successfully 2023 137397
# Webpage fetched successfully 2023 82037
# Webpage fetched successfully 2024 162202
# Webpage fetched successfully 2023 93992
# Webpage fetched successfully 2024 161221
# Webpage fetched successfully 2023 204504
# Webpage fetched successfully 2023 178757
# Webpage fetched successfully 2024 131764
# Webpage fetched successfully 2023 120270
# Webpage fetched successfully 2024 273765
# Webpage fetched successfully 2024 112841
# Webpage fetched successfully 2024 211291
# Webpage fetched successfully 2023 322368
# Webpage fetched successfully 2024 107031
# Webpage fetched successfully 2023 287854
# Webpage fetched successfully 2024 223484
# Webpage fetched successfully 2024 361921
# Webpage fetched successfully 2023 335736
# Webpage fetched successfully 2023 423178
# Webpage fetched successfully 2024 256788
# Webpage fetched successfully 2024 78326
# Webpage fetched successfully 2024 480050
# Webpage fetched successfully 2024 165777
# Webpage fetched successfully 2024 154436
# Webpage fetched successfully 2023 290755
# Webpage fetched successfully 2023 411041
# Webpage fetched successfully 2023 247633
# Webpage fetched successfully 2024 284919
# Webpage fetched successfully 2023 326212
# Webpage fetched successfully 2024 133704
# Webpage fetched successfully 2023 481111
# Webpage fetched successfully 2024 72012
# Webpage fetched successfully 2024 169620
# Webpage fetched successfully 2023 246909
# Webpage fetched successfully 2024 100088
# Webpage fetched successfully 2024 360116
# Webpage fetched successfully 2023 179356
# Webpage fetched successfully 2023 25167
# https://nvd.nist.gov/vuln/detail/CVE-2023-25167/	Discourse is an open source discussion platform. In affected versions a malicious user can cause a regular expression denial of service using a carefully crafted git URL. This issue is patched in the latest stable, beta and tests-passed versions of Discourse. Users are advised to upgrade. There are no known workarounds for this issue.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Discourse is an open source discussion platform. In affected versions a malicious user can cause a regular expression denial of service using a carefully crafted git URL. This issue is patched in the latest stable, beta and tests-passed versions of Discourse. Users are advised to upgrade. There are no known workarounds for this issue.	CWE-13333
#
# Webpage fetched successfully 2024 324192
# Webpage fetched successfully 2023 158590
# Webpage fetched successfully 2023 404099
# Webpage fetched successfully 2023 483809
# Webpage fetched successfully 2024 261676
# Webpage fetched successfully 2024 79767
# Webpage fetched successfully 2024 319187
# Webpage fetched successfully 2023 67210
# Webpage fetched successfully 2023 50593
# Webpage fetched successfully 2024 182682
# Webpage fetched successfully 2023 149806
# Webpage fetched successfully 2024 346480
# Webpage fetched successfully 2023 73756
# Webpage fetched successfully 2024 262046
# Webpage fetched successfully 2024 416181
# Webpage fetched successfully 2023 174237
# Webpage fetched successfully 2023 36986
# Webpage fetched successfully 2024 446476
# Webpage fetched successfully 2024 472978
# Webpage fetched successfully 2023 72033
# Webpage fetched successfully 2023 494550
# Webpage fetched successfully 2024 442589
# Webpage fetched successfully 2023 14566
# Webpage fetched successfully 2023 450327
# Webpage fetched successfully 2024 95942
# Webpage fetched successfully 2024 456646
# Webpage fetched successfully 2023 101797
# Webpage fetched successfully 2023 403168
# Webpage fetched successfully 2023 347421
# Webpage fetched successfully 2023 496702
# Webpage fetched successfully 2023 48786
# Webpage fetched successfully 2024 357724
# Webpage fetched successfully 2023 359106
# Webpage fetched successfully 2024 403103
# Webpage fetched successfully 2024 479448
# Webpage fetched successfully 2023 112449
# Webpage fetched successfully 2023 62523
# Webpage fetched successfully 2024 335963
# Webpage fetched successfully 2023 138288
# Webpage fetched successfully 2024 361490
# Webpage fetched successfully 2024 410979
# Webpage fetched successfully 2024 26698
# Webpage fetched successfully 2024 495877
# Webpage fetched successfully 2023 84771
# Webpage fetched successfully 2023 55637
# Webpage fetched successfully 2023 95250
# Webpage fetched successfully 2023 460595
# Webpage fetched successfully 2023 130838
# Webpage fetched successfully 2024 391586
# Webpage fetched successfully 2023 38612
# Webpage fetched successfully 2024 114781
# Webpage fetched successfully 2024 38951
# Webpage fetched successfully 2024 105659
# Webpage fetched successfully 2023 58719
# Webpage fetched successfully 2024 37477
# Webpage fetched successfully 2024 146742
# Webpage fetched successfully 2023 464758
# Webpage fetched successfully 2024 495733
# Webpage fetched successfully 2024 318176
# Webpage fetched successfully 2024 271632
# Webpage fetched successfully 2023 69010
# Webpage fetched successfully 2024 14130
# Webpage fetched successfully 2023 343730
# Webpage fetched successfully 2024 243385
# Webpage fetched successfully 2024 14016
# Webpage fetched successfully 2024 168652
# Webpage fetched successfully 2024 490269
# Webpage fetched successfully 2024 34059
# Webpage fetched successfully 2023 130924
# Webpage fetched successfully 2023 44690
# https://nvd.nist.gov/vuln/detail/CVE-2023-44690/	Inadequate encryption strength in mycli 1.27.0 allows attackers to view sensitive information via /mycli/config.py	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Inadequate encryption strength in mycli 1.27.0 allows attackers to view sensitive information via /mycli/config.py	CWE-3264
#
# Webpage fetched successfully 2024 382497
# Webpage fetched successfully 2023 125085
# Webpage fetched successfully 2024 402137
# Webpage fetched successfully 2024 213907
# Webpage fetched successfully 2024 126017
# Webpage fetched successfully 2023 322196
# Webpage fetched successfully 2023 33398
# Webpage fetched successfully 2024 315605
# Webpage fetched successfully 2024 169227
# Webpage fetched successfully 2024 121413
# Webpage fetched successfully 2023 223267
# Webpage fetched successfully 2024 446976
# Webpage fetched successfully 2023 384754
# Webpage fetched successfully 2024 417999
# Webpage fetched successfully 2024 43987
# Webpage fetched successfully 2024 358420
# Webpage fetched successfully 2024 116704
# Webpage fetched successfully 2024 78996
# Webpage fetched successfully 2023 199015
# Webpage fetched successfully 2023 212279
# Webpage fetched successfully 2023 353389
# Webpage fetched successfully 2024 420501
# Webpage fetched successfully 2023 451376
# Webpage fetched successfully 2023 25757
# Webpage fetched successfully 2023 446781
# Webpage fetched successfully 2023 363576
# Webpage fetched successfully 2024 113161
# Webpage fetched successfully 2023 238370
# Webpage fetched successfully 2023 199059
# Webpage fetched successfully 2023 181567
# Webpage fetched successfully 2023 109948
# Webpage fetched successfully 2023 210085
# Webpage fetched successfully 2024 255986
# Webpage fetched successfully 2024 177546
# Webpage fetched successfully 2023 79242
# Webpage fetched successfully 2023 486030
# Webpage fetched successfully 2024 370262
# Webpage fetched successfully 2024 421054
# Webpage fetched successfully 2024 102319
# Webpage fetched successfully 2024 42653
# Webpage fetched successfully 2024 459659
# Webpage fetched successfully 2024 443325
# Webpage fetched successfully 2023 292155
# Webpage fetched successfully 2024 261975
# Webpage fetched successfully 2023 164360
# Webpage fetched successfully 2024 351304
# Webpage fetched successfully 2023 194900
# Webpage fetched successfully 2024 124502
# Webpage fetched successfully 2024 245688
# Webpage fetched successfully 2024 171720
# Webpage fetched successfully 2024 176974
# Webpage fetched successfully 2024 50795
# Webpage fetched successfully 2023 336273
# Webpage fetched successfully 2023 393787
# Webpage fetched successfully 2023 437101
# Webpage fetched successfully 2023 221515
# Webpage fetched successfully 2024 357948
# Webpage fetched successfully 2024 399819
# Webpage fetched successfully 2024 345219
# Webpage fetched successfully 2024 395638
# Webpage fetched successfully 2023 387555
# Webpage fetched successfully 2023 221135
# Webpage fetched successfully 2023 167869
# Webpage fetched successfully 2024 206965
# Webpage fetched successfully 2024 387489
# Webpage fetched successfully 2024 374498
# Webpage fetched successfully 2024 204808
# Webpage fetched successfully 2023 226625
# Webpage fetched successfully 2023 413568
# Webpage fetched successfully 2024 281351
# Webpage fetched successfully 2023 426483
# Webpage fetched successfully 2024 222981
# Webpage fetched successfully 2024 473530
# Webpage fetched successfully 2023 340381
# Webpage fetched successfully 2024 394777
# Webpage fetched successfully 2023 8918
# Webpage fetched successfully 2024 370819
# Webpage fetched successfully 2023 388282
# Webpage fetched successfully 2024 131387
# Webpage fetched successfully 2023 408575
# Webpage fetched successfully 2023 377655
# Webpage fetched successfully 2024 129697
# Webpage fetched successfully 2024 453045
# Webpage fetched successfully 2023 475064
# Webpage fetched successfully 2024 465550
# Webpage fetched successfully 2024 13051
# Webpage fetched successfully 2024 153692
# Webpage fetched successfully 2024 465310
# Webpage fetched successfully 2023 296964
# Webpage fetched successfully 2023 438688
# Webpage fetched successfully 2024 436308
# Webpage fetched successfully 2024 412909
# Webpage fetched successfully 2024 160430
# Webpage fetched successfully 2023 475930
# Webpage fetched successfully 2024 51246
# Webpage fetched successfully 2024 481138
# Webpage fetched successfully 2023 390643
# Webpage fetched successfully 2024 224726
# Webpage fetched successfully 2023 101682
# Webpage fetched successfully 2023 218730
# Webpage fetched successfully 2024 180610
# Webpage fetched successfully 2024 242253
# Webpage fetched successfully 2023 371124
# Webpage fetched successfully 2024 36408
# https://nvd.nist.gov/vuln/detail/CVE-2024-36408/	SuiteCRM is an open-source Customer Relationship Management (CRM) software application. In versions prior to 7.14.4 and 8.6.1, poor input validation allows for SQL Injection in the `Alerts` controller. Versions 7.14.4 and 8.6.1 contain a fix for this issue.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:SuiteCRM is an open-source Customer Relationship Management (CRM) software application. In versions prior to 7.14.4 and 8.6.1, poor input validation allows for SQL Injection in the `Alerts` controller. Versions 7.14.4 and 8.6.1 contain a fix for this issue.	CWE-895
#
# Webpage fetched successfully 2024 404426
# Webpage fetched successfully 2023 467171
# Webpage fetched successfully 2024 292344
# Webpage fetched successfully 2024 493447
# Webpage fetched successfully 2023 312997
# Webpage fetched successfully 2024 159256
# Webpage fetched successfully 2023 271343
# Webpage fetched successfully 2023 434541
# Webpage fetched successfully 2024 196326
# Webpage fetched successfully 2024 359025
# Webpage fetched successfully 2023 76115
# Webpage fetched successfully 2023 343851
# Webpage fetched successfully 2023 41701
# Webpage fetched successfully 2023 191419
# Webpage fetched successfully 2024 498122
# Webpage fetched successfully 2023 12052
# Webpage fetched successfully 2024 454893
# Webpage fetched successfully 2024 127753
# Webpage fetched successfully 2023 482448
# Webpage fetched successfully 2024 172217
# Webpage fetched successfully 2024 357142
# Webpage fetched successfully 2023 217379
# Webpage fetched successfully 2024 49125
# Webpage fetched successfully 2024 398198
# Webpage fetched successfully 2023 410478
# Webpage fetched successfully 2023 304291
# Webpage fetched successfully 2023 68586
# Webpage fetched successfully 2024 216679
# Webpage fetched successfully 2023 255767
# Webpage fetched successfully 2023 325141
# Webpage fetched successfully 2024 386290
# Webpage fetched successfully 2023 104170
# Webpage fetched successfully 2024 75687
# Webpage fetched successfully 2023 391676
# Webpage fetched successfully 2024 225138
# Webpage fetched successfully 2023 271931
# Webpage fetched successfully 2023 472965
# Webpage fetched successfully 2024 206963
# Webpage fetched successfully 2023 28376
# https://nvd.nist.gov/vuln/detail/CVE-2023-28376/	Out-of-bounds read in the firmware for some Intel(R) E810 Ethernet Controllers and Adapters before version 1.7.1 may allow an unauthenticated user to potentially enable denial of service via adjacent access.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Out-of-bounds read in the firmware for some Intel(R) E810 Ethernet Controllers and Adapters before version 1.7.1 may allow an unauthenticated user to potentially enable denial of service via adjacent access.	CWE-1256
#
# Webpage fetched successfully 2023 306084
# Webpage fetched successfully 2023 455497
# Webpage fetched successfully 2023 73556
# Webpage fetched successfully 2024 329194
# Webpage fetched successfully 2023 413047
# Webpage fetched successfully 2023 157193
# Webpage fetched successfully 2024 87830
# Webpage fetched successfully 2024 128642
# Webpage fetched successfully 2024 477296
# Webpage fetched successfully 2024 110522
# Webpage fetched successfully 2023 167996
# Webpage fetched successfully 2023 434287
# Webpage fetched successfully 2024 61097
# Webpage fetched successfully 2023 231171
# Webpage fetched successfully 2023 368292
# Webpage fetched successfully 2023 132160
# Webpage fetched successfully 2023 225638
# Webpage fetched successfully 2024 400656
# Webpage fetched successfully 2024 320834
# Webpage fetched successfully 2024 266249
# Webpage fetched successfully 2023 171429
# Webpage fetched successfully 2023 3027
# https://nvd.nist.gov/vuln/detail/CVE-2023-3027/	The grc-policy-propagator allows security escalation within the cluster. The propagator allows policies which contain some dynamically obtained values (instead of the policy apply a static manifest on a managed cluster) of taking advantage of cluster scoped access in a created policy. This feature does not restrict properly to lookup content from the namespace where the policy was created.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:The grc-policy-propagator allows security escalation within the cluster. The propagator allows policies which contain some dynamically obtained values (instead of the policy apply a static manifest on a managed cluster) of taking advantage of cluster scoped access in a created policy. This feature does not restrict properly to lookup content from the namespace where the policy was created.	CWE-2697
#
# Webpage fetched successfully 2024 165979
# Webpage fetched successfully 2023 306326
# Webpage fetched successfully 2024 129778
# Webpage fetched successfully 2024 471401
# Webpage fetched successfully 2023 481122
# Webpage fetched successfully 2024 61702
# Webpage fetched successfully 2024 279670
# Webpage fetched successfully 2024 458500
# Webpage fetched successfully 2023 7722
# Webpage fetched successfully 2024 203465
# Webpage fetched successfully 2023 157948
# Webpage fetched successfully 2024 21353
# Webpage fetched successfully 2024 60992
# Webpage fetched successfully 2024 7501
# Webpage fetched successfully 2023 168327
# Webpage fetched successfully 2024 65275
# Webpage fetched successfully 2023 439661
# Webpage fetched successfully 2024 255008
# Webpage fetched successfully 2024 212461
# Webpage fetched successfully 2024 293402
# Webpage fetched successfully 2023 20988
# https://nvd.nist.gov/vuln/detail/CVE-2023-20988/	In btm_read_rssi_complete of btm_acl.cc, there is a possible out of bounds read due to a missing bounds check. This could lead to local information disclosure in the Bluetooth server with System execution privileges needed. User interaction is not needed for exploitation.Product: AndroidVersions: Android-13Android ID: A-260569232	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:In btm_read_rssi_complete of btm_acl.cc, there is a possible out of bounds read due to a missing bounds check. This could lead to local information disclosure in the Bluetooth server with System execution privileges needed. User interaction is not needed for exploitation.Product: AndroidVersions: Android-13Android ID: A-260569232	CWE-1258
#
# Webpage fetched successfully 2023 310547
# Webpage fetched successfully 2024 414866
# Webpage fetched successfully 2023 207855
# Webpage fetched successfully 2024 33219
# Webpage fetched successfully 2023 113273
# Webpage fetched successfully 2024 317735
# Webpage fetched successfully 2023 228064
# Webpage fetched successfully 2023 133610
# Webpage fetched successfully 2023 440247
# Webpage fetched successfully 2023 487796
# Webpage fetched successfully 2023 315180
# Webpage fetched successfully 2024 60007
# Webpage fetched successfully 2024 319882
# Webpage fetched successfully 2023 254270
# Webpage fetched successfully 2024 148431
# Webpage fetched successfully 2023 480336
# Webpage fetched successfully 2024 474140
# Webpage fetched successfully 2023 457680
# Webpage fetched successfully 2024 388148
# Webpage fetched successfully 2024 74364
# Webpage fetched successfully 2023 384545
# Webpage fetched successfully 2023 358784
# Webpage fetched successfully 2023 481631
# Webpage fetched successfully 2023 381162
# Webpage fetched successfully 2023 187189
# Webpage fetched successfully 2024 217503
# Webpage fetched successfully 2024 340909
# Webpage fetched successfully 2024 65432
# Webpage fetched successfully 2023 305130
# Webpage fetched successfully 2024 32189
# Webpage fetched successfully 2023 191480
# Webpage fetched successfully 2023 204550
# Webpage fetched successfully 2023 120909
# Webpage fetched successfully 2023 311404
# Webpage fetched successfully 2023 32235
# https://nvd.nist.gov/vuln/detail/CVE-2023-32235/	Ghost before 5.42.1 allows remote attackers to read arbitrary files within the active theme's folder via /assets/built%2F..%2F..%2F/ directory traversal. This occurs in frontend/web/middleware/static-theme.js.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Ghost before 5.42.1 allows remote attackers to read arbitrary files within the active theme's folder via /assets/built%2F..%2F..%2F/ directory traversal. This occurs in frontend/web/middleware/static-theme.js.	CWE-229
#
# Webpage fetched successfully 2024 100035
# Webpage fetched successfully 2023 349824
# Webpage fetched successfully 2023 158427
# Webpage fetched successfully 2023 175561
# Webpage fetched successfully 2023 18899
# Webpage fetched successfully 2024 198626
# Webpage fetched successfully 2023 205472
# Webpage fetched successfully 2024 313072
# Webpage fetched successfully 2024 440501
# Webpage fetched successfully 2023 54792
# Webpage fetched successfully 2024 315710
# Webpage fetched successfully 2024 412875
# Webpage fetched successfully 2024 125168
# Webpage fetched successfully 2023 100596
# Webpage fetched successfully 2023 381300
# Webpage fetched successfully 2024 323994
# Webpage fetched successfully 2024 119681
# Webpage fetched successfully 2023 475732
# Webpage fetched successfully 2023 365126
# Webpage fetched successfully 2023 429950
# Webpage fetched successfully 2024 145995
# Webpage fetched successfully 2023 14782
# Webpage fetched successfully 2024 65418
# Webpage fetched successfully 2024 220788
# Webpage fetched successfully 2023 231552
# Webpage fetched successfully 2024 219998
# Webpage fetched successfully 2024 322525
# Webpage fetched successfully 2023 451453
# Webpage fetched successfully 2024 344590
# Webpage fetched successfully 2024 136907
# Webpage fetched successfully 2024 477358
# Webpage fetched successfully 2024 493026
# Webpage fetched successfully 2024 59610
# Webpage fetched successfully 2024 308762
# Webpage fetched successfully 2024 143472
# Webpage fetched successfully 2024 389135
# Webpage fetched successfully 2023 289292
# Webpage fetched successfully 2024 100448
# Webpage fetched successfully 2024 497149
# Webpage fetched successfully 2024 343064
# Webpage fetched successfully 2023 446724
# Webpage fetched successfully 2024 136024
# Webpage fetched successfully 2024 308755
# Webpage fetched successfully 2023 208245
# Webpage fetched successfully 2023 25089
# https://nvd.nist.gov/vuln/detail/CVE-2023-25089/	Multiple buffer overflow vulnerabilities exist in the vtysh_ubus binary of Milesight UR32L v32.3.0.5 due to the use of an unsafe sprintf pattern. A specially crafted HTTP request can lead to arbitrary code execution. An attacker with high privileges can send HTTP requests to trigger these vulnerabilities.This buffer overflow occurs in the handle_interface_acl function with the interface variable when in_acl is -1.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Multiple buffer overflow vulnerabilities exist in the vtysh_ubus binary of Milesight UR32L v32.3.0.5 due to the use of an unsafe sprintf pattern. A specially crafted HTTP request can lead to arbitrary code execution. An attacker with high privileges can send HTTP requests to trigger these vulnerabilities.This buffer overflow occurs in the handle_interface_acl function with the interface variable when in_acl is -1.	CWE-78710
#
# Webpage fetched successfully 2024 431751
# Webpage fetched successfully 2023 352823
# Webpage fetched successfully 2023 64769
# Webpage fetched successfully 2024 305877
# Webpage fetched successfully 2023 473049
# Webpage fetched successfully 2023 264958
# Webpage fetched successfully 2023 12702
# Webpage fetched successfully 2024 404170
# Webpage fetched successfully 2024 287507
# Webpage fetched successfully 2023 183737
# Webpage fetched successfully 2023 485373
# Webpage fetched successfully 2023 226088
# Webpage fetched successfully 2024 77437
# Webpage fetched successfully 2023 312199
# Webpage fetched successfully 2023 44108
# https://nvd.nist.gov/vuln/detail/CVE-2023-44108/	Type confusion vulnerability in the distributed file module.Successful exploitation of this vulnerability may cause the device to restart.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Type confusion vulnerability in the distributed file module.Successful exploitation of this vulnerability may cause the device to restart.	CWE-84311
#
# Webpage fetched successfully 2023 367864
# Webpage fetched successfully 2023 238749
# Webpage fetched successfully 2023 40327
# Webpage fetched successfully 2024 207055
# Webpage fetched successfully 2023 159043
# Webpage fetched successfully 2023 241072
# Webpage fetched successfully 2023 26708
# Webpage fetched successfully 2024 486156
# Webpage fetched successfully 2023 96480
# Webpage fetched successfully 2023 194309
# Webpage fetched successfully 2023 359046
# Webpage fetched successfully 2023 42951
# Webpage fetched successfully 2023 447634
# Webpage fetched successfully 2024 395861
# Webpage fetched successfully 2024 448464
# Webpage fetched successfully 2024 155461
# Webpage fetched successfully 2024 107417
# Webpage fetched successfully 2023 292628
# Webpage fetched successfully 2023 326102
# Webpage fetched successfully 2023 410015
# Webpage fetched successfully 2024 53595
# Webpage fetched successfully 2024 399908
# Webpage fetched successfully 2024 334222
# Webpage fetched successfully 2024 119946
# Webpage fetched successfully 2024 268215
# Webpage fetched successfully 2024 166495
# Webpage fetched successfully 2023 369354
# Webpage fetched successfully 2023 429025
# Webpage fetched successfully 2023 192804
# Webpage fetched successfully 2024 191966
# Webpage fetched successfully 2024 417764
# Webpage fetched successfully 2024 339375
# Webpage fetched successfully 2023 480753
# Webpage fetched successfully 2023 35958
# https://nvd.nist.gov/vuln/detail/CVE-2023-35958/	Multiple heap-based buffer overflow vulnerabilities exist in the fstReaderIterBlocks2 VCDATA parsing functionality of GTKWave 3.3.115. A specially-crafted .fst file can lead to arbitrary code execution. A victim would need to open a malicious file to trigger these vulnerabilities.This vulnerability concerns the copy function `fstFread`.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Multiple heap-based buffer overflow vulnerabilities exist in the fstReaderIterBlocks2 VCDATA parsing functionality of GTKWave 3.3.115. A specially-crafted .fst file can lead to arbitrary code execution. A victim would need to open a malicious file to trigger these vulnerabilities.This vulnerability concerns the copy function `fstFread`.	CWE-11912
#
# Webpage fetched successfully 2024 422809
# Webpage fetched successfully 2024 283313
# Webpage fetched successfully 2023 344104
# Webpage fetched successfully 2023 192893
# Webpage fetched successfully 2023 71132
# Webpage fetched successfully 2023 221547
# Webpage fetched successfully 2023 34342
# https://nvd.nist.gov/vuln/detail/CVE-2023-34342/	AMI BMC contains a vulnerability in the IPMI handler, where anattacker can upload and download arbitrary files under certain circumstances,which may lead to denial of service, escalation of privileges, informationdisclosure, or data tampering.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:AMI BMC contains a vulnerability in the IPMI handler, where anattacker can upload and download arbitrary files under certain circumstances,which may lead to denial of service, escalation of privileges, informationdisclosure, or data tampering.	CWE-2213
#
# Webpage fetched successfully 2024 424187
# Webpage fetched successfully 2024 258422
# Webpage fetched successfully 2023 72252
# Webpage fetched successfully 2023 81993
# Webpage fetched successfully 2024 118674
# Webpage fetched successfully 2023 441082
# Webpage fetched successfully 2024 450392
# Webpage fetched successfully 2023 412850
# Webpage fetched successfully 2023 476899
# Webpage fetched successfully 2024 254139
# Webpage fetched successfully 2024 286807
# Webpage fetched successfully 2024 60123
# Webpage fetched successfully 2024 272028
# Webpage fetched successfully 2023 192342
# Webpage fetched successfully 2024 102125
# Webpage fetched successfully 2023 92380
# Webpage fetched successfully 2023 72070
# Webpage fetched successfully 2024 258889
# Webpage fetched successfully 2023 325093
# Webpage fetched successfully 2023 217692
# Webpage fetched successfully 2024 233752
# Webpage fetched successfully 2023 223104
# Webpage fetched successfully 2023 214026
# Webpage fetched successfully 2023 281649
# Webpage fetched successfully 2023 29421
# https://nvd.nist.gov/vuln/detail/CVE-2023-29421/	An issue was discovered in libbzip3.a in bzip3 before 1.2.3. There is an out-of-bounds write in bz3_decode_block.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:An issue was discovered in libbzip3.a in bzip3 before 1.2.3. There is an out-of-bounds write in bz3_decode_block.	CWE-78714
#
# Webpage fetched successfully 2024 466292
# Webpage fetched successfully 2024 341991
# Webpage fetched successfully 2024 20533
# Webpage fetched successfully 2023 170271
# Webpage fetched successfully 2024 452988
# Webpage fetched successfully 2023 336055
# Webpage fetched successfully 2023 264666
# Webpage fetched successfully 2023 72500
# Webpage fetched successfully 2024 82376
# Webpage fetched successfully 2023 265784
# Webpage fetched successfully 2024 226912
# Webpage fetched successfully 2024 357869
# Webpage fetched successfully 2024 277855
# Webpage fetched successfully 2023 285631
# Webpage fetched successfully 2023 23505
# https://nvd.nist.gov/vuln/detail/CVE-2023-23505/	A privacy issue was addressed with improved private data redaction for log entries. This issue is fixed in macOS Monterey 12.6.3, macOS Ventura 13.2, watchOS 9.3, macOS Big Sur 11.7.3, iOS 15.7.3 and iPadOS 15.7.3, iOS 16.3 and iPadOS 16.3. An app may be able to access information about a user’s contacts.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:A privacy issue was addressed with improved private data redaction for log entries. This issue is fixed in macOS Monterey 12.6.3, macOS Ventura 13.2, watchOS 9.3, macOS Big Sur 11.7.3, iOS 15.7.3 and iPadOS 15.7.3, iOS 16.3 and iPadOS 16.3. An app may be able to access information about a user’s contacts.	CWE-53215
#
# Webpage fetched successfully 2024 106634
# Webpage fetched successfully 2024 467223
# Webpage fetched successfully 2024 369490
# Webpage fetched successfully 2023 410923
# Webpage fetched successfully 2023 85084
# Webpage fetched successfully 2023 105160
# Webpage fetched successfully 2023 395160
# Webpage fetched successfully 2023 244627
# Webpage fetched successfully 2024 273733
# Webpage fetched successfully 2023 465341
# Webpage fetched successfully 2023 277570
# Webpage fetched successfully 2023 188668
# Webpage fetched successfully 2024 56050
# Webpage fetched successfully 2023 185921
# Webpage fetched successfully 2024 177591
# Webpage fetched successfully 2023 397382
# Webpage fetched successfully 2024 53070
# Webpage fetched successfully 2024 202470
# Webpage fetched successfully 2023 474477
# Webpage fetched successfully 2024 428218
# Webpage fetched successfully 2023 274106
# Webpage fetched successfully 2024 293650
# Webpage fetched successfully 2024 94417
# Webpage fetched successfully 2024 89323
# Webpage fetched successfully 2023 203591
# Webpage fetched successfully 2023 303618
# Webpage fetched successfully 2024 202441
# Webpage fetched successfully 2024 61888
# Webpage fetched successfully 2023 458264
# Webpage fetched successfully 2024 421024
# Webpage fetched successfully 2023 83879
# Webpage fetched successfully 2023 224443
# Webpage fetched successfully 2023 169480
# Webpage fetched successfully 2023 263686
# Webpage fetched successfully 2023 118121
# Webpage fetched successfully 2023 137234
# Webpage fetched successfully 2024 471577
# Webpage fetched successfully 2024 365206
# Webpage fetched successfully 2024 278659
# Webpage fetched successfully 2024 52252
# Webpage fetched successfully 2024 121368
# Webpage fetched successfully 2023 20677
# https://nvd.nist.gov/vuln/detail/CVE-2023-20677/	In wlan, there is a possible out of bounds read due to a missing bounds check. This could lead to local information disclosure with System execution privileges needed. User interaction is not needed for exploitation. Patch ID: ALPS07588413; Issue ID: ALPS07588436.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:In wlan, there is a possible out of bounds read due to a missing bounds check. This could lead to local information disclosure with System execution privileges needed. User interaction is not needed for exploitation. Patch ID: ALPS07588413; Issue ID: ALPS07588436.	CWE-12516
#
# Webpage fetched successfully 2023 69211
# Webpage fetched successfully 2023 348903
# Webpage fetched successfully 2024 369584
# Webpage fetched successfully 2023 344362
# Webpage fetched successfully 2024 294721
# Webpage fetched successfully 2023 223252
# Webpage fetched successfully 2024 453280
# Webpage fetched successfully 2023 197267
# Webpage fetched successfully 2024 139069
# Webpage fetched successfully 2024 286207
# Webpage fetched successfully 2024 340397
# Webpage fetched successfully 2024 364259
# Webpage fetched successfully 2023 422361
# Webpage fetched successfully 2024 354583
# Webpage fetched successfully 2023 171539
# Webpage fetched successfully 2023 332434
# Webpage fetched successfully 2024 22746
# Webpage fetched successfully 2023 496219
# Webpage fetched successfully 2023 411380
# Webpage fetched successfully 2024 76352
# Webpage fetched successfully 2023 380430
# Webpage fetched successfully 2024 159684
# Webpage fetched successfully 2023 23274
# Webpage fetched successfully 2024 264516
# Webpage fetched successfully 2024 63731
# Webpage fetched successfully 2023 296658
# Webpage fetched successfully 2024 47746
# Webpage fetched successfully 2023 124449
# Webpage fetched successfully 2023 383319
# Webpage fetched successfully 2024 418284
# Webpage fetched successfully 2024 193692
# Webpage fetched successfully 2024 413471
# Webpage fetched successfully 2024 108018
# Webpage fetched successfully 2023 488463
# Webpage fetched successfully 2024 303988
# Webpage fetched successfully 2023 309274
# Webpage fetched successfully 2024 396715
# Webpage fetched successfully 2023 361297
# Webpage fetched successfully 2023 133763
# Webpage fetched successfully 2024 310511
# Webpage fetched successfully 2023 353660
# Webpage fetched successfully 2023 381839
# Webpage fetched successfully 2024 271944
# Webpage fetched successfully 2023 469368
# Webpage fetched successfully 2024 19673
# Webpage fetched successfully 2024 31907
# https://nvd.nist.gov/vuln/detail/CVE-2024-31907/	IBM Planning Analytics Local 2.0 and 2.1 is vulnerable to cross-site scripting. This vulnerability allows users to embed arbitrary JavaScript code in the Web UI thus altering the intended functionality potentially leading to credentials disclosure within a trusted session.  IBM X-Force ID:  289889.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:IBM Planning Analytics Local 2.0 and 2.1 is vulnerable to cross-site scripting. This vulnerability allows users to embed arbitrary JavaScript code in the Web UI thus altering the intended functionality potentially leading to credentials disclosure within a trusted session.  IBM X-Force ID:  289889.	CWE-7917
#
# Webpage fetched successfully 2023 286848
# Webpage fetched successfully 2023 390813
# Webpage fetched successfully 2024 230568
# Webpage fetched successfully 2024 496090
# Webpage fetched successfully 2024 295378
# Webpage fetched successfully 2024 33058
# Webpage fetched successfully 2024 477917
# Webpage fetched successfully 2024 289934
# Webpage fetched successfully 2024 263956
# Webpage fetched successfully 2023 268599
# Webpage fetched successfully 2024 185054
# Webpage fetched successfully 2023 24432
# https://nvd.nist.gov/vuln/detail/CVE-2023-24432/	A cross-site request forgery (CSRF) vulnerability in Jenkins Orka by MacStadium Plugin 1.31 and earlier allows attackers to connect to an attacker-specified HTTP server using attacker-specified credentials IDs obtained through another method, capturing credentials stored in Jenkins.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:A cross-site request forgery (CSRF) vulnerability in Jenkins Orka by MacStadium Plugin 1.31 and earlier allows attackers to connect to an attacker-specified HTTP server using attacker-specified credentials IDs obtained through another method, capturing credentials stored in Jenkins.	CWE-35218
#
# Webpage fetched successfully 2023 185041
# Webpage fetched successfully 2024 225924
# Webpage fetched successfully 2023 90665
# Webpage fetched successfully 2023 305482
# Webpage fetched successfully 2023 476236
# Webpage fetched successfully 2023 169417
# Webpage fetched successfully 2024 84567
# Webpage fetched successfully 2023 313070
# Webpage fetched successfully 2024 24644
# Webpage fetched successfully 2023 421150
# Webpage fetched successfully 2024 273206
# Webpage fetched successfully 2023 395545
# Webpage fetched successfully 2024 14001
# Webpage fetched successfully 2024 279605
# Webpage fetched successfully 2023 303533
# Webpage fetched successfully 2023 475083
# Webpage fetched successfully 2023 116278
# Webpage fetched successfully 2024 185859
# Webpage fetched successfully 2023 51437
# https://nvd.nist.gov/vuln/detail/CVE-2023-51437/	Observable timing discrepancy vulnerability in Apache Pulsar SASL Authentication Provider can allow an attacker to forge a SASL Role Token that will pass signature verification.Users are recommended to upgrade to version 2.11.3, 3.0.2, or 3.1.1 which fixes the issue. Users should also consider updating the configured secret in the `saslJaasServerRoleTokenSignerSecretPath` file.Any component matching an above version running the SASL Authentication Provider is affected. That includes the Pulsar Broker, Proxy, Websocket Proxy, or Function Worker.2.11 Pulsar users should upgrade to at least 2.11.3.3.0 Pulsar users should upgrade to at least 3.0.2.3.1 Pulsar users should upgrade to at least 3.1.1.Any users running Pulsar 2.8, 2.9, 2.10, and earlier should upgrade to one of the above patched versions.For additional details on this attack vector, please refer to  https://codahale.com/a-lesson-in-timing-attacks/ .	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Observable timing discrepancy vulnerability in Apache Pulsar SASL Authentication Provider can allow an attacker to forge a SASL Role Token that will pass signature verification.Users are recommended to upgrade to version 2.11.3, 3.0.2, or 3.1.1 which fixes the issue. Users should also consider updating the configured secret in the `saslJaasServerRoleTokenSignerSecretPath` file.Any component matching an above version running the SASL Authentication Provider is affected. That includes the Pulsar Broker, Proxy, Websocket Proxy, or Function Worker.2.11 Pulsar users should upgrade to at least 2.11.3.3.0 Pulsar users should upgrade to at least 3.0.2.3.1 Pulsar users should upgrade to at least 3.1.1.Any users running Pulsar 2.8, 2.9, 2.10, and earlier should upgrade to one of the above patched versions.For additional details on this attack vector, please refer to  https://codahale.com/a-lesson-in-timing-attacks/ .	CWE-20319
#
# Webpage fetched successfully 2023 432080
# Webpage fetched successfully 2023 52515
# Webpage fetched successfully 2024 112790
# Webpage fetched successfully 2024 192516
# Webpage fetched successfully 2023 344339
# Webpage fetched successfully 2023 109244
# Webpage fetched successfully 2023 168419
# Webpage fetched successfully 2024 79968
# Webpage fetched successfully 2024 200131
# Webpage fetched successfully 2023 382624
# Webpage fetched successfully 2024 47981
# Webpage fetched successfully 2023 138547
# Webpage fetched successfully 2024 483107
# Webpage fetched successfully 2023 16444
# Webpage fetched successfully 2024 9599
# Webpage fetched successfully 2023 287629
# Webpage fetched successfully 2024 1084
# https://nvd.nist.gov/vuln/detail/CVE-2024-1084/	Cross-site Scripting in the tag name pattern field in the tag protections UI in GitHub Enterprise Server allows a malicious website that requires user interaction and social engineering to make changes to a user account via CSP bypass with created CSRF tokens. This vulnerability affected all versions of GitHub Enterprise Server prior to 3.12  and was fixed in all versions of 3.11.5, 3.10.7, 3.9.10, and 3.8.15. This vulnerability was reported via the GitHub Bug Bounty program.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Cross-site Scripting in the tag name pattern field in the tag protections UI in GitHub Enterprise Server allows a malicious website that requires user interaction and social engineering to make changes to a user account via CSP bypass with created CSRF tokens. This vulnerability affected all versions of GitHub Enterprise Server prior to 3.12  and was fixed in all versions of 3.11.5, 3.10.7, 3.9.10, and 3.8.15. This vulnerability was reported via the GitHub Bug Bounty program.	CWE-7920
#
# Webpage fetched successfully 2024 319079
# Webpage fetched successfully 2024 329162
# Webpage fetched successfully 2023 29500
# Webpage fetched successfully 2024 374853
# Webpage fetched successfully 2024 457311
# Webpage fetched successfully 2023 264126
# Webpage fetched successfully 2023 69704
# Webpage fetched successfully 2023 435333
# Webpage fetched successfully 2024 452098
# Webpage fetched successfully 2023 302490
# Webpage fetched successfully 2023 142084
# Webpage fetched successfully 2023 383413
# Webpage fetched successfully 2023 294813
# Webpage fetched successfully 2023 123409
# Webpage fetched successfully 2024 258004
# Webpage fetched successfully 2024 188886
# Webpage fetched successfully 2024 58896
# Webpage fetched successfully 2023 242250
# Webpage fetched successfully 2023 147719
# Webpage fetched successfully 2024 258814
# Webpage fetched successfully 2023 385518
# Webpage fetched successfully 2024 440083
# Webpage fetched successfully 2024 122198
# Webpage fetched successfully 2023 345539
# Webpage fetched successfully 2024 237631
# Webpage fetched successfully 2024 338640
# Webpage fetched successfully 2023 485250
# Webpage fetched successfully 2024 157398
# Webpage fetched successfully 2024 411723
# Webpage fetched successfully 2024 241316
# Webpage fetched successfully 2024 276520
# Webpage fetched successfully 2024 212633
# Webpage fetched successfully 2023 183931
# Webpage fetched successfully 2023 220547
# Webpage fetched successfully 2024 95176
# Webpage fetched successfully 2024 485088
# Webpage fetched successfully 2024 152343
# Webpage fetched successfully 2023 301441
# Webpage fetched successfully 2023 290855
# Webpage fetched successfully 2024 176044
# Webpage fetched successfully 2023 137407
# Webpage fetched successfully 2023 214882
# Webpage fetched successfully 2023 434017
# Webpage fetched successfully 2023 457724
# Webpage fetched successfully 2024 27902
# ...
# Webpage fetched successfully 2023 304556
# Webpage fetched successfully 2024 417022
# Webpage fetched successfully 2023 490260
# Webpage fetched successfully 2023 208736
# Webpage fetched successfully 2024 489331
# Webpage fetched successfully 2024 421019
# Webpage fetched successfully 2023 59859
# Webpage fetched successfully 2023 209496
# Webpage fetched successfully 2023 363515
# Webpage fetched successfully 2024 453613
# Webpage fetched successfully 2024 487417
# Webpage fetched successfully 2024 414088
# Webpage fetched successfully 2023 412378
# Webpage fetched successfully 2023 434113
# Webpage fetched successfully 2023 64384
# Webpage fetched successfully 2024 26233
# https://nvd.nist.gov/vuln/detail/CVE-2024-26233/	Windows DNS Server Remote Code Execution Vulnerability	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Windows DNS Server Remote Code Execution Vulnerability	CWE-41673
#
# Webpage fetched successfully 2024 20571
# Webpage fetched successfully 2024 66155
# Webpage fetched successfully 2024 147137
# Webpage fetched successfully 2023 155206
# Webpage fetched successfully 2024 446337
# Webpage fetched successfully 2023 294665
# Webpage fetched successfully 2023 69733
# Webpage fetched successfully 2023 418075
# Webpage fetched successfully 2024 196786
# Webpage fetched successfully 2023 296232
# Webpage fetched successfully 2023 68540
# Webpage fetched successfully 2023 61302
# Webpage fetched successfully 2024 393888
# Webpage fetched successfully 2023 316211
# Webpage fetched successfully 2023 210299
# Webpage fetched successfully 2024 446870
# Webpage fetched successfully 2023 191976
# Webpage fetched successfully 2023 211178
# Webpage fetched successfully 2024 459483
# Webpage fetched successfully 2024 45404
# Webpage fetched successfully 2024 171329
# Webpage fetched successfully 2023 488055
# Webpage fetched successfully 2023 330904
# Webpage fetched successfully 2023 299547
# Webpage fetched successfully 2024 120294
# Webpage fetched successfully 2023 407160
# Webpage fetched successfully 2024 256918
# Webpage fetched successfully 2024 202051
# Webpage fetched successfully 2024 171967
# Webpage fetched successfully 2023 216757
# Webpage fetched successfully 2024 296847
# Webpage fetched successfully 2023 472938
# Webpage fetched successfully 2023 498837
# Webpage fetched successfully 2023 181660
# Webpage fetched successfully 2023 204892
# Webpage fetched successfully 2023 332166
# Webpage fetched successfully 2023 471480
# Webpage fetched successfully 2023 40169
# Webpage fetched successfully 2024 235091
# Webpage fetched successfully 2023 248606
# Webpage fetched successfully 2024 473340
# Webpage fetched successfully 2024 414639
# Webpage fetched successfully 2023 295497
# Webpage fetched successfully 2023 24836
# https://nvd.nist.gov/vuln/detail/CVE-2023-24836/	SUNNET CTMS has vulnerability of path traversal within its file uploading function. An authenticated remote attacker with general user privilege can exploit this vulnerability to upload and execute scripts onto arbitrary directories to perform arbitrary system operation or disrupt service.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:SUNNET CTMS has vulnerability of path traversal within its file uploading function. An authenticated remote attacker with general user privilege can exploit this vulnerability to upload and execute scripts onto arbitrary directories to perform arbitrary system operation or disrupt service.	CWE-2274
#
# Webpage fetched successfully 2023 383594
# Webpage fetched successfully 2024 155403
# Webpage fetched successfully 2024 376633
# Webpage fetched successfully 2024 353985
# Webpage fetched successfully 2024 49782
# Webpage fetched successfully 2024 170259
# Webpage fetched successfully 2024 166024
# Webpage fetched successfully 2024 168880
# Webpage fetched successfully 2024 18043
# Webpage fetched successfully 2023 475635
# Webpage fetched successfully 2024 369128
# Webpage fetched successfully 2024 198117
# Webpage fetched successfully 2023 267982
# Webpage fetched successfully 2023 16752
# Webpage fetched successfully 2024 234774
# Webpage fetched successfully 2024 51246
# Webpage fetched successfully 2023 456020
# Webpage fetched successfully 2024 452519
# Webpage fetched successfully 2024 117306
# Webpage fetched successfully 2023 436801
# Webpage fetched successfully 2024 116242
# Webpage fetched successfully 2023 182529
# Webpage fetched successfully 2023 388880
# Webpage fetched successfully 2023 201711
# Webpage fetched successfully 2024 4359
# Webpage fetched successfully 2024 112901
# Webpage fetched successfully 2023 52340
# Webpage fetched successfully 2023 203853
# Webpage fetched successfully 2023 114647
# Webpage fetched successfully 2023 302719
# Webpage fetched successfully 2024 255255
# Webpage fetched successfully 2023 256551
# Webpage fetched successfully 2023 444391
# Webpage fetched successfully 2023 450204
# Webpage fetched successfully 2023 277466
# Webpage fetched successfully 2024 61682
# Webpage fetched successfully 2024 431232
# Webpage fetched successfully 2023 156167
# Webpage fetched successfully 2024 291644
# Webpage fetched successfully 2024 324353
# Webpage fetched successfully 2024 214389
# Webpage fetched successfully 2023 20479
# Webpage fetched successfully 2024 354661
# Webpage fetched successfully 2023 484611
# Webpage fetched successfully 2023 260396
# Webpage fetched successfully 2023 122960
# Webpage fetched successfully 2023 205916
# Webpage fetched successfully 2023 208377
# Webpage fetched successfully 2023 181546
# Webpage fetched successfully 2024 136982
# Webpage fetched successfully 2023 55843
# Webpage fetched successfully 2023 455921
# Webpage fetched successfully 2023 262365
# Webpage fetched successfully 2023 2349
# https://nvd.nist.gov/vuln/detail/CVE-2023-2349/	A vulnerability classified as problematic has been found in SourceCodester Service Provider Management System 1.0. Affected is an unknown function of the file /admin/index.php. The manipulation of the argument page leads to cross site scripting. It is possible to launch the attack remotely. The exploit has been disclosed to the public and may be used. The identifier of this vulnerability is VDB-227592.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:A vulnerability classified as problematic has been found in SourceCodester Service Provider Management System 1.0. Affected is an unknown function of the file /admin/index.php. The manipulation of the argument page leads to cross site scripting. It is possible to launch the attack remotely. The exploit has been disclosed to the public and may be used. The identifier of this vulnerability is VDB-227592.	CWE-7975
#
# Webpage fetched successfully 2024 341482
# Webpage fetched successfully 2023 135587
# Webpage fetched successfully 2024 499172
# Webpage fetched successfully 2023 284829
# Webpage fetched successfully 2024 52042
# Webpage fetched successfully 2023 463827
# Webpage fetched successfully 2024 111840
# Webpage fetched successfully 2024 410619
# Webpage fetched successfully 2024 45954
# Webpage fetched successfully 2023 141809
# Webpage fetched successfully 2024 72416
# Webpage fetched successfully 2023 184558
# Webpage fetched successfully 2024 374973
# Webpage fetched successfully 2024 39764
# Webpage fetched successfully 2023 203820
# Webpage fetched successfully 2024 335081
# Webpage fetched successfully 2023 231590
# Webpage fetched successfully 2024 278410
# Webpage fetched successfully 2024 300241
# Webpage fetched successfully 2023 470298
# Webpage fetched successfully 2024 327764
# Webpage fetched successfully 2023 107233
# Webpage fetched successfully 2023 54994
# Webpage fetched successfully 2023 122723
# Webpage fetched successfully 2024 214444
# Webpage fetched successfully 2024 322873
# Webpage fetched successfully 2023 365764
# Webpage fetched successfully 2023 340790
# Webpage fetched successfully 2023 77429
# Webpage fetched successfully 2023 339735
# Webpage fetched successfully 2023 311579
# Webpage fetched successfully 2024 419086
# Webpage fetched successfully 2024 254914
# Webpage fetched successfully 2023 270616
# Webpage fetched successfully 2023 385813
# Webpage fetched successfully 2023 18417
# Webpage fetched successfully 2023 496674
# Webpage fetched successfully 2023 257827
# Webpage fetched successfully 2023 315407
# Webpage fetched successfully 2024 119752
# Webpage fetched successfully 2023 444203
# Webpage fetched successfully 2023 492107
# Webpage fetched successfully 2024 442622
# Webpage fetched successfully 2023 459729
# Webpage fetched successfully 2024 370666
# Webpage fetched successfully 2024 158615
# Webpage fetched successfully 2024 316510
# Webpage fetched successfully 2023 244346
# Webpage fetched successfully 2024 361789
# Webpage fetched successfully 2024 2348
# Webpage fetched successfully 2023 304321
# Webpage fetched successfully 2023 469397
# Webpage fetched successfully 2023 127521
# Webpage fetched successfully 2023 165046
# Webpage fetched successfully 2024 346260
# Webpage fetched successfully 2024 181717
# Webpage fetched successfully 2023 451049
# Webpage fetched successfully 2023 421522
# Webpage fetched successfully 2023 45867
# https://nvd.nist.gov/vuln/detail/CVE-2023-45867/	ILIAS (2013-09-12 release) contains a medium-criticality Directory Traversal local file inclusion vulnerability in the ScormAicc module. An attacker with a privileged account, typically holding the tutor role, can exploit this to gain unauthorized access to and potentially retrieve confidential files stored on the web server. The attacker can access files that are readable by the web server user www-data; this may include sensitive configuration files and documents located outside the documentRoot. The vulnerability is exploited by an attacker who manipulates the file parameter in a URL, inserting directory traversal sequences in order to access unauthorized files. This manipulation allows the attacker to retrieve sensitive files, such as /etc/passwd, potentially compromising the system's security. This issue poses a significant risk to confidentiality and is remotely exploitable over the internet.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:ILIAS (2013-09-12 release) contains a medium-criticality Directory Traversal local file inclusion vulnerability in the ScormAicc module. An attacker with a privileged account, typically holding the tutor role, can exploit this to gain unauthorized access to and potentially retrieve confidential files stored on the web server. The attacker can access files that are readable by the web server user www-data; this may include sensitive configuration files and documents located outside the documentRoot. The vulnerability is exploited by an attacker who manipulates the file parameter in a URL, inserting directory traversal sequences in order to access unauthorized files. This manipulation allows the attacker to retrieve sensitive files, such as /etc/passwd, potentially compromising the system's security. This issue poses a significant risk to confidentiality and is remotely exploitable over the internet.	NVD-CWE-Other76
#
# Webpage fetched successfully 2023 478827
# Webpage fetched successfully 2024 187938
# Webpage fetched successfully 2024 25276
# Webpage fetched successfully 2024 349763
# Webpage fetched successfully 2023 50007
# https://nvd.nist.gov/vuln/detail/CVE-2023-50007/	Buffer Overflow vulnerability in Ffmpeg v.n6.1-3-g466799d4f5 allows a local attacker to execute arbitrary code via theav_samples_set_silence function in thelibavutil/samplefmt.c:260:9 component.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:Buffer Overflow vulnerability in Ffmpeg v.n6.1-3-g466799d4f5 allows a local attacker to execute arbitrary code via theav_samples_set_silence function in thelibavutil/samplefmt.c:260:9 component.	CWE-12177
#
# Webpage fetched successfully 2024 3987
# Webpage fetched successfully 2024 348387
# Webpage fetched successfully 2023 219661
# Webpage fetched successfully 2023 449317
# Webpage fetched successfully 2024 129689
# Webpage fetched successfully 2024 303115
# Webpage fetched successfully 2024 41571
# Webpage fetched successfully 2023 340232
# Webpage fetched successfully 2024 373511
# Webpage fetched successfully 2024 256618
# Webpage fetched successfully 2023 23456
# https://nvd.nist.gov/vuln/detail/CVE-2023-23456/	A heap-based buffer overflow issue was discovered in UPX in PackTmt::pack() in p_tmt.cpp file. The flow allows an attacker to cause a denial of service (abort) via a crafted file.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:A heap-based buffer overflow issue was discovered in UPX in PackTmt::pack() in p_tmt.cpp file. The flow allows an attacker to cause a denial of service (abort) via a crafted file.	CWE-78778
#
# Webpage fetched successfully 2023 276228
# Webpage fetched successfully 2024 171069
# Webpage fetched successfully 2023 172835
# Webpage fetched successfully 2024 138494
# Webpage fetched successfully 2024 134678
# Webpage fetched successfully 2024 423656
# Webpage fetched successfully 2023 374925
# Webpage fetched successfully 2023 304772
# Webpage fetched successfully 2023 107286
# Webpage fetched successfully 2024 39722
# Webpage fetched successfully 2023 203778
# Webpage fetched successfully 2024 166860
# Webpage fetched successfully 2024 229735
# Webpage fetched successfully 2024 478772
# Webpage fetched successfully 2023 148078
# Webpage fetched successfully 2023 245074
# Webpage fetched successfully 2024 137811
# Webpage fetched successfully 2024 381770
# Webpage fetched successfully 2023 143103
# Webpage fetched successfully 2024 10946
# Webpage fetched successfully 2024 348500
# Webpage fetched successfully 2023 179580
# Webpage fetched successfully 2024 224124
# Webpage fetched successfully 2024 396686
# Webpage fetched successfully 2023 83902
# Webpage fetched successfully 2024 20853
# Webpage fetched successfully 2023 345519
# Webpage fetched successfully 2023 352763
# Webpage fetched successfully 2024 331079
# Webpage fetched successfully 2024 477589
# Webpage fetched successfully 2023 72138
# Webpage fetched successfully 2024 467488
# Webpage fetched successfully 2023 481732
# Webpage fetched successfully 2024 202091
# Webpage fetched successfully 2024 148861
# Webpage fetched successfully 2023 290457
# Webpage fetched successfully 2024 16676
# Webpage fetched successfully 2024 494750
# Webpage fetched successfully 2024 338667
# Webpage fetched successfully 2024 305178
# Webpage fetched successfully 2024 326027
# Webpage fetched successfully 2023 211816
# Webpage fetched successfully 2023 32990
# https://nvd.nist.gov/vuln/detail/CVE-2023-32990/	A missing permission check in Jenkins Azure VM Agents Plugin 852.v8d35f0960a_43 and earlier allows attackers with Overall/Read permission to connect to an attacker-specified Azure Cloud server using attacker-specified credentials IDs obtained through another method.	Analyze the following CVE description and map it to the appropriate CWE. Provide a brief justification for your choice. Ensure the last line of your response contains only the CWE ID.  CVE Description:A missing permission check in Jenkins Azure VM Agents Plugin 852.v8d35f0960a_43 and earlier allows attackers with Overall/Read permission to connect to an attacker-specified Azure Cloud server using attacker-specified credentials IDs obtained through another method.	CWE-73279
#
# Webpage fetched successfully 2024 190997
# Webpage fetched successfully 2023 187697

# %% [markdown]
# # CTI-VSP

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup


links = pd.read_csv("cti_rcm_generated.tsv", sep="\t", encoding='latin1')['URL']

with open('cti_vsp_generated.tsv', 'a') as file:
        file.write('URL'+'\t'+'Description'+'\t'+'Prompt'+'\t'+'GT'+'\n')
        for link in links:
            # Fetch the webpage
            response = requests.get(link)
            
            # Check if the request was successful
            if response.status_code == 200:
                webpage_content = response.text
                print('Webpage fetched successfully', link)
            
                # Parse the HTML content using BeautifulSoup
                soup = BeautifulSoup(webpage_content, 'html.parser')
        
                vuln_description = soup.find('p', {'data-testid': 'vuln-description'})
        
                gt = soup.find('span', {'data-testid': 'vuln-cvss3-nist-vector'})
                
                if gt is None:
                    gt = soup.find('span', {'data-testid': 'vuln-cvss3-cna-vector'})
        
                if vuln_description and gt:
                    description_text = vuln_description.get_text()
                    gt_text = gt.get_text()
                    #print(description_text, cwes_text)
                    prompt = "Analyze the following CVE description and calculate the CVSS v3.1 Base Score. Determine the values for each base metric: AV, AC, PR, UI, S, C, I, and A. Summarize each metric's value and provide the final CVSS v3.1 vector string.   Valid options for each metric are as follows: - **Attack Vector (AV)**: Network (N), Adjacent (A), Local (L), Physical (P) - **Attack Complexity (AC)**: Low (L), High (H) - **Privileges Required (PR)**: None (N), Low (L), High (H) - **User Interaction (UI)**: None (N), Required (R) - **Scope (S)**: Unchanged (U), Changed (C) - **Confidentiality (C)**: None (N), Low (L), High (H) - **Integrity (I)**: None (N), Low (L), High (H) - **Availability (A)**: None (N), Low (L), High (H)  Summarize each metric's value and provide the final CVSS v3.1 vector string. Ensure the final line of your response contains only the CVSS v3 Vector String in the following format:  Example format: CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H  CVE Description: " + description_text
                    file.write(link + '\t' + description_text.replace('\n', '') + '\t' + prompt.replace('\n', '') + '\t' + gt_text.replace('\n', '') + '\n')
                    #print(link + '\t' + description_text.replace('\n', '') + '\t' + prompt.replace('\n', '') + '\t' + gt_text.replace('\n', '') + '\n')
            else:
                print(link, response.status_code)
# Out:
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3027/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32462/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-39821/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-7133/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39544/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38905/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-42299/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-26032/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-26173/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2669/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6560/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3938/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2548/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-37270/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5465/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39306/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-26089/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-40307/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-37859/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-22997/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-4495/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47578/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47558/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2040/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-35709/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-34286/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23120/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-31229/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-35212/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-39691/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-25836/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-33684/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-30030/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25928/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-22481/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-35649/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28970/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1082/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6531/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52372/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-29101/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-33917/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1714/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-3135/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-31095/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-26155/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23892/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-30270/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47174/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27019/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-26061/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1118/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48695/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-31422/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22139/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-37948/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48462/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38255/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-40639/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25601/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32578/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-5950/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33022/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-27091/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2826/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2649/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-34992/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-31580/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32260/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-21652/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39061/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-22392/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-30550/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39970/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-27291/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24213/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27635/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-31919/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33228/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-4696/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-39571/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-40603/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3543/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-37256/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25696/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51514/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-34304/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-36774/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32406/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-26782/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3462/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-33835/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-3544/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6875/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28578/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45742/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50019/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-29824/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24999/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38454/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49003/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1143/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32372/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-26222/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-35758/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1918/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38124/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-6152/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-20801/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32869/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-31409/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45580/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3466/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-37710/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5096/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-36213/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-34274/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50854/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32429/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-35703/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6575/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-7171/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33026/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39187/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-25086/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24940/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-29073/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-5542/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-34384/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39292/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-4539/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33118/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27320/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-28868/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1532/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52308/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-35210/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-25540/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1914/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-42075/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-40486/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2522/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2089/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-23545/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-44228/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-34750/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-35210/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5904/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28824/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38690/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-5256/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-31245/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21178/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-5444/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27628/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-6006/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5344/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-24652/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2669/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5544/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-28939/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-41710/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-37195/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-30153/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32958/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6072/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6516/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-39686/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-29032/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28508/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38552/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-31083/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25552/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49486/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-36472/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-41669/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-22624/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28692/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39500/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33376/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-36984/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6599/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-31946/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45871/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-6794/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32460/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-23650/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1156/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-5453/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-29317/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2634/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27206/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-27307/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21361/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-36926/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2694/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5944/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-3914/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-25432/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52204/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-26469/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32217/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2494/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-42095/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-30798/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50275/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-36993/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38160/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3774/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6948/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-29044/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50949/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-33590/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-7067/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-37920/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-37019/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-30077/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-34335/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-34209/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-33831/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28314/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28981/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39949/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49436/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-29055/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21368/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1604/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32791/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-20722/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-34380/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6732/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-30321/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1078/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32482/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3774/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48559/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1152/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2620/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28737/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21487/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-40416/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-41663/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-3121/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-27903/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-4505/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-5507/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-40141/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-4236/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22208/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-4744/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-7123/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-29024/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-29108/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-4523/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23473/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23912/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-4449/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32053/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2214/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49569/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-30373/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-29478/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22298/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-22432/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33027/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22107/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46402/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2564/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21661/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39249/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-29912/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-38773/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-41948/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6199/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-35181/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32978/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-41808/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2435/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-39927/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22237/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-26388/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-42632/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2063/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49149/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-20614/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-24501/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-43102/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5403/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5079/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52118/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32236/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27163/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1209/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47775/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-26924/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21273/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-38429/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-23704/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28684/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32404/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-42428/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-33300/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-43357/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-41285/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45673/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28682/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25927/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32827/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25935/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-5552/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46222/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38000/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-29193/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-40035/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27868/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-37507/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-33644/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27298/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-21725/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-29096/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2209/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-37206/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23439/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5378/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1618/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-33000/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-7219/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39544/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-23808/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32025/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3774/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-26089/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-26769/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47107/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25395/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-28909/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-4982/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23057/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-27957/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28606/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21712/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47207/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22830/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-4969/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-6468/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27720/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25982/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-33927/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48344/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1548/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-20632/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-3046/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-4728/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-35184/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-43857/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-6416/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-4122/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-43321/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-4301/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39498/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-40509/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-24452/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6768/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1046/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1095/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2574/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22445/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45135/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-36923/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-26568/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-25895/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5044/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3062/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3015/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-36356/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-30335/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-38701/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22394/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-6755/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39957/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2090/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-23871/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32719/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23838/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2742/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28074/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-36750/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-42075/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21019/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38417/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-7198/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-26401/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-6104/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-41786/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2450/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-20634/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38618/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46149/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32313/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-31082/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-33410/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-30545/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5641/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-23457/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-35647/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-25762/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-5983/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5120/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-37539/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2883/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38874/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48524/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50019/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48848/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45673/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-36522/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1523/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33284/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-34921/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-21473/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-31361/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-35661/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1635/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-33326/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5414/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-35698/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50572/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-29837/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-4543/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32281/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5181/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27982/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32556/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-4698/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32621/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2695/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24845/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-36840/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-43798/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6027/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-37387/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-3536/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-4623/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27581/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-31664/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24946/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23890/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-30583/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-40509/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27899/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6899/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-23560/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27640/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21487/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33524/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33180/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-7261/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32831/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28017/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1632/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-29095/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-30264/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47219/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23860/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5751/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-23490/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38106/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-31746/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-42053/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-25668/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3576/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-23809/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-6185/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-31256/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32134/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-4864/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46993/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6247/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1462/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38948/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-4835/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28088/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46863/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33912/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27579/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49810/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21052/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22113/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-32464/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52237/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49657/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-3746/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-35428/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-27629/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2580/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21000/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1315/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1941/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-22695/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21391/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-3441/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-21843/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-3414/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5796/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2052/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27979/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3792/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49490/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-30955/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48766/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-24148/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52448/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38106/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46129/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-6318/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39685/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-34414/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-29833/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48388/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2217/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45819/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22729/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-35635/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5813/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28726/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-21535/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25149/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-28969/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5297/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-7033/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1110/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-22923/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-34109/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1974/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-24517/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-29305/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50465/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-34929/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45188/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-40842/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-22475/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-36408/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1965/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-24523/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1355/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49148/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48205/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33368/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-35139/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33635/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49333/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3688/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49502/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25048/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-44323/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-36071/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33875/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-37219/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3119/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2094/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45134/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2796/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1928/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51106/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-7172/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-22441/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25699/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-24507/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-6957/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51736/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6319/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-20742/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-37213/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38029/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32759/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27867/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-24373/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-2777/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-29909/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-36671/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45393/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23360/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-34205/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-27977/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-43813/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52602/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25269/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5523/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-4356/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38702/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48838/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1243/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-39876/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-1719/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46505/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-4744/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-33621/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-43535/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-2950/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47119/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-25167/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-44690/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-36408/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28376/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-3027/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-20988/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32235/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-25089/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-44108/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-35958/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-34342/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-29421/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-23505/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-20677/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-31907/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-24432/
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51437/
# ...
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25298
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-41279
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51733
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25418
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2021-46915
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0473
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0195
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47200
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23054
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22230
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22194
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48202
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5130
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-26593
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-31211
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47458
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0362
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1022
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51722
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23867
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24331
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2020-26623
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39302
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48357
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22286
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-40414
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23750
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2021-46931
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46838
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52064
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23614
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0941
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52323
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24311
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24753
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48341
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52038
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22914
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52434
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2021-46930
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52443
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2022-41790
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22291
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25140
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25710
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52452
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22213
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38587
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0193
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0564
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23034
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1072
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32378
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51954
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-4925
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48342
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46712
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52457
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52645
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45036
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0349
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50136
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2020-29504
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22432
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46739
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22211
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50019
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22639
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0714
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-21733
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24260
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6374
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50948
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6064
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51506
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24146
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2021-43584
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-49295
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-7063
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38323
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46805
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24810
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48259
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24713
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0235
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22491
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-42143
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0997
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51711
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0565
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-28897
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51488
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5956
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-38677
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48247
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-29472
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2022-45177
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22916
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-7238
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0844
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2022-48657
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25106
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0729
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24021
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0603
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1017
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22195
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-1190
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25308
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23885
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52118
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-21619
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-46308
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-21851
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47534
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32329
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-21917
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0225
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50061
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52130
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-50974
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52435
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23876
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0605
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52426
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-20012
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0733
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0606
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51924
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-41178
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5800
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0507
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45213
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2022-40361
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52121
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25207
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51126
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-31031
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0962
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-48243
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-20010
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24388
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52448
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-25145
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24130
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2022-48655
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24399
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-39197
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0500
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-21632
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51955
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-21910
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-45187
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6620
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0299
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52128
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-51493
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-24135
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-26157
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-22141
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-40265
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52149
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0268
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-42766
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52288
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-5691
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-47353
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2019-25160
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24861
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-0389
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52120
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23902
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-52463
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-6535
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-23553
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2022-45845
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0885
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2021-24559
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-7170
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-24469
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2023-32451
# Webpage fetched successfully https://nvd.nist.gov/vuln/detail/CVE-2024-0738
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[4], line 34
#      32         #print(description_text, cwes_text)
#      33         prompt = "Analyze the following CVE description and calculate the CVSS v3.1 Base Score. Determine the values for each base metric: AV, AC, PR, UI, S, C, I, and A. Summarize each metric's value and provide the final CVSS v3.1 vector string.   Valid options for each metric are as follows: - **Attack Vector (AV)**: Network (N), Adjacent (A), Local (L), Physical (P) - **Attack Complexity (AC)**: Low (L), High (H) - **Privileges Required (PR)**: None (N), Low (L), High (H) - **User Interaction (UI)**: None (N), Required (R) - **Scope (S)**: Unchanged (U), Changed (C) - **Confidentiality (C)**: None (N), Low (L), High (H) - **Integrity (I)**: None (N), Low (L), High (H) - **Availability (A)**: None (N), Low (L), High (H)  Summarize each metric's value and provide the final CVSS v3.1 vector string. Ensure the final line of your response contains only the CVSS v3 Vector String in the following format:  Example format: CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H  CVE Description: " + description_text
# ---> 34         file.write(link + '\t' + description_text.replace('\n', '') + '\t' + prompt.replace('\n', '') + '\t' + gt_text.replace('\n', '') + '\n')
#      35         #print(link + '\t' + description_text.replace('\n', '') + '\t' + prompt.replace('\n', '') + '\t' + gt_text.replace('\n', '') + '\n')
#      36 else:
#      37     print(link, response.status_code)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 116-119: character maps to <undefined>
